# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
#  80%|████████  | 1165/1452 [04:41<01:09,  4.11it/s]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64, activation="relu")(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 6s 3ms/step - loss: 0.3838 - matthews_correlation: 0.0000e+00 - val_loss: 0.2371 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.2307 - matthews_correlation: 0.0000e+00 - val_loss: 0.2297 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.2322 - matthews_correlation: 0.0000e+00 - val_loss: 0.2338 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 1s 512us/step - loss: 0.2217 - matthews_correlation: 0.0000e+00 - val_loss: 0.2260 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 1s 505us/step - loss: 0.2195 - matthews_correlation: 0.0000e+00 - val_loss: 0.2131 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.2023 - matthews_correlation: 0.0000e+00 - val_loss: 0.2040 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.2021 - matthews_correlation: -0.0017 - val_loss: 0.2186 - val_matthews_correlation: 0.2192
#
# Epoch 00007: val_matthews_correlation improved from 0.00000 to 0.21918, saving model to weights_0.h5
# Epoch 8/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1900 - matthews_correlation: 0.0836 - val_loss: 0.1797 - val_matthews_correlation: 0.2192
#
# Epoch 00008: val_matthews_correlation did not improve from 0.21918
# Epoch 9/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.1642 - matthews_correlation: 0.1492 - val_loss: 0.1725 - val_matthews_correlation: 0.4000
#
# Epoch 00009: val_matthews_correlation improved from 0.21918 to 0.40004, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 1s 514us/step - loss: 0.1508 - matthews_correlation: 0.3135 - val_loss: 0.1104 - val_matthews_correlation: 0.4656
#
# Epoch 00010: val_matthews_correlation improved from 0.40004 to 0.46559, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.1177 - matthews_correlation: 0.5418 - val_loss: 0.1062 - val_matthews_correlation: 0.7326
#
# Epoch 00011: val_matthews_correlation improved from 0.46559 to 0.73256, saving model to weights_0.h5
# Epoch 12/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.1147 - matthews_correlation: 0.5933 - val_loss: 0.0813 - val_matthews_correlation: 0.7846
#
# Epoch 00012: val_matthews_correlation improved from 0.73256 to 0.78462, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.1200 - matthews_correlation: 0.5892 - val_loss: 0.0956 - val_matthews_correlation: 0.7352
#
# Epoch 00013: val_matthews_correlation did not improve from 0.78462
# Epoch 14/50
# 2322/2322 [==============================] - 1s 514us/step - loss: 0.1053 - matthews_correlation: 0.6446 - val_loss: 0.1025 - val_matthews_correlation: 0.5810
#
# Epoch 00014: val_matthews_correlation did not improve from 0.78462
# Epoch 15/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1190 - matthews_correlation: 0.4992 - val_loss: 0.0848 - val_matthews_correlation: 0.7204
#
# Epoch 00015: val_matthews_correlation did not improve from 0.78462
# Epoch 16/50
# 2322/2322 [==============================] - 1s 510us/step - loss: 0.1022 - matthews_correlation: 0.6394 - val_loss: 0.0863 - val_matthews_correlation: 0.7807
#
# Epoch 00016: val_matthews_correlation did not improve from 0.78462
# Epoch 17/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.1021 - matthews_correlation: 0.6542 - val_loss: 0.0812 - val_matthews_correlation: 0.7901
#
# Epoch 00017: val_matthews_correlation improved from 0.78462 to 0.79006, saving model to weights_0.h5
# Epoch 18/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1031 - matthews_correlation: 0.6164 - val_loss: 0.0746 - val_matthews_correlation: 0.8271
#
# Epoch 00018: val_matthews_correlation improved from 0.79006 to 0.82710, saving model to weights_0.h5
# Epoch 19/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.1035 - matthews_correlation: 0.6687 - val_loss: 0.0878 - val_matthews_correlation: 0.7963
#
# Epoch 00019: val_matthews_correlation did not improve from 0.82710
# Epoch 20/50
# 2322/2322 [==============================] - 1s 513us/step - loss: 0.1074 - matthews_correlation: 0.5826 - val_loss: 0.0885 - val_matthews_correlation: 0.6261
#
# Epoch 00020: val_matthews_correlation did not improve from 0.82710
# Epoch 21/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.1081 - matthews_correlation: 0.6348 - val_loss: 0.0825 - val_matthews_correlation: 0.7317
#
# Epoch 00021: val_matthews_correlation did not improve from 0.82710
# Epoch 22/50
# 2322/2322 [==============================] - 1s 510us/step - loss: 0.0974 - matthews_correlation: 0.6225 - val_loss: 0.0811 - val_matthews_correlation: 0.7869
#
# Epoch 00022: val_matthews_correlation did not improve from 0.82710
# Epoch 23/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0912 - matthews_correlation: 0.6815 - val_loss: 0.0976 - val_matthews_correlation: 0.7026
#
# Epoch 00023: val_matthews_correlation did not improve from 0.82710
# Epoch 24/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0907 - matthews_correlation: 0.6852 - val_loss: 0.0781 - val_matthews_correlation: 0.8103
#
# Epoch 00024: val_matthews_correlation did not improve from 0.82710
# Epoch 25/50
# 2322/2322 [==============================] - 1s 505us/step - loss: 0.0912 - matthews_correlation: 0.6784 - val_loss: 0.0807 - val_matthews_correlation: 0.7685
#
# Epoch 00025: val_matthews_correlation did not improve from 0.82710
# Epoch 26/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.0955 - matthews_correlation: 0.6564 - val_loss: 0.0755 - val_matthews_correlation: 0.7711
#
# Epoch 00026: val_matthews_correlation did not improve from 0.82710
# Epoch 27/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.0940 - matthews_correlation: 0.6702 - val_loss: 0.0757 - val_matthews_correlation: 0.7600
#
# Epoch 00027: val_matthews_correlation did not improve from 0.82710
# Epoch 28/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.0941 - matthews_correlation: 0.6996 - val_loss: 0.0709 - val_matthews_correlation: 0.8012
#
# Epoch 00028: val_matthews_correlation did not improve from 0.82710
# Epoch 29/50
# 2322/2322 [==============================] - 1s 512us/step - loss: 0.0922 - matthews_correlation: 0.6959 - val_loss: 0.0814 - val_matthews_correlation: 0.7766
#
# Epoch 00029: val_matthews_correlation did not improve from 0.82710
# Epoch 30/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0883 - matthews_correlation: 0.6761 - val_loss: 0.0731 - val_matthews_correlation: 0.8122
#
# Epoch 00030: val_matthews_correlation did not improve from 0.82710
# Epoch 31/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.0871 - matthews_correlation: 0.7274 - val_loss: 0.0813 - val_matthews_correlation: 0.8173
#
# Epoch 00031: val_matthews_correlation did not improve from 0.82710
# Epoch 32/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0901 - matthews_correlation: 0.7075 - val_loss: 0.0876 - val_matthews_correlation: 0.6569
#
# Epoch 00032: val_matthews_correlation did not improve from 0.82710
# Epoch 33/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.1010 - matthews_correlation: 0.6182 - val_loss: 0.0779 - val_matthews_correlation: 0.7489
#
# Epoch 00033: val_matthews_correlation did not improve from 0.82710
# Epoch 34/50
# 2322/2322 [==============================] - 1s 506us/step - loss: 0.0928 - matthews_correlation: 0.6666 - val_loss: 0.0833 - val_matthews_correlation: 0.7303
#
# Epoch 00034: val_matthews_correlation did not improve from 0.82710
# Epoch 35/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0889 - matthews_correlation: 0.7005 - val_loss: 0.0766 - val_matthews_correlation: 0.8328
#
# Epoch 00035: val_matthews_correlation improved from 0.82710 to 0.83280, saving model to weights_0.h5
# Epoch 36/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.0920 - matthews_correlation: 0.6989 - val_loss: 0.1258 - val_matthews_correlation: 0.6645
#
# Epoch 00036: val_matthews_correlation did not improve from 0.83280
# Epoch 37/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.0947 - matthews_correlation: 0.6896 - val_loss: 0.0919 - val_matthews_correlation: 0.7696
#
# Epoch 00037: val_matthews_correlation did not improve from 0.83280
# Epoch 38/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0905 - matthews_correlation: 0.6984 - val_loss: 0.0834 - val_matthews_correlation: 0.8140
#
# Epoch 00038: val_matthews_correlation did not improve from 0.83280
# Epoch 39/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0865 - matthews_correlation: 0.7113 - val_loss: 0.0877 - val_matthews_correlation: 0.7903
#
# Epoch 00039: val_matthews_correlation did not improve from 0.83280
# Epoch 40/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0856 - matthews_correlation: 0.7099 - val_loss: 0.0886 - val_matthews_correlation: 0.8072
#
# Epoch 00040: val_matthews_correlation did not improve from 0.83280
# Epoch 41/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0812 - matthews_correlation: 0.7606 - val_loss: 0.0793 - val_matthews_correlation: 0.8096
#
# Epoch 00041: val_matthews_correlation did not improve from 0.83280
# Epoch 42/50
# 2322/2322 [==============================] - 1s 510us/step - loss: 0.0806 - matthews_correlation: 0.7307 - val_loss: 0.0774 - val_matthews_correlation: 0.8130
#
# Epoch 00042: val_matthews_correlation did not improve from 0.83280
# Epoch 43/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.0774 - matthews_correlation: 0.7163 - val_loss: 0.0758 - val_matthews_correlation: 0.7869
#
# Epoch 00043: val_matthews_correlation did not improve from 0.83280
# Epoch 44/50
# 2322/2322 [==============================] - 1s 507us/step - loss: 0.0755 - matthews_correlation: 0.7224 - val_loss: 0.0937 - val_matthews_correlation: 0.7502
#
# Epoch 00044: val_matthews_correlation did not improve from 0.83280
# Epoch 45/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.0781 - matthews_correlation: 0.7053 - val_loss: 0.0978 - val_matthews_correlation: 0.7671
#
# Epoch 00045: val_matthews_correlation did not improve from 0.83280
# Epoch 46/50
# 2322/2322 [==============================] - 1s 506us/step - loss: 0.0845 - matthews_correlation: 0.6953 - val_loss: 0.0892 - val_matthews_correlation: 0.7799
#
# Epoch 00046: val_matthews_correlation did not improve from 0.83280
# Epoch 47/50
# 2322/2322 [==============================] - 1s 512us/step - loss: 0.0804 - matthews_correlation: 0.7447 - val_loss: 0.0873 - val_matthews_correlation: 0.7078
#
# Epoch 00047: val_matthews_correlation did not improve from 0.83280
# Epoch 48/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.0961 - matthews_correlation: 0.6725 - val_loss: 0.0920 - val_matthews_correlation: 0.8050
#
# Epoch 00048: val_matthews_correlation did not improve from 0.83280
# Epoch 49/50
# 2322/2322 [==============================] - 1s 510us/step - loss: 0.0929 - matthews_correlation: 0.6804 - val_loss: 0.0847 - val_matthews_correlation: 0.8116
#
# Epoch 00049: val_matthews_correlation did not improve from 0.83280
# Epoch 50/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.0832 - matthews_correlation: 0.7057 - val_loss: 0.0770 - val_matthews_correlation: 0.7606
#
# Epoch 00050: val_matthews_correlation did not improve from 0.83280
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 995us/step - loss: 0.3492 - matthews_correlation: 0.0000e+00 - val_loss: 0.2306 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 511us/step - loss: 0.2324 - matthews_correlation: 0.0000e+00 - val_loss: 0.2259 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.2127 - matthews_correlation: 0.0568 - val_loss: 0.2250 - val_matthews_correlation: 0.0903
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.09028, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 1s 516us/step - loss: 0.1990 - matthews_correlation: 0.1825 - val_loss: 0.1936 - val_matthews_correlation: 0.0781
#
# Epoch 00004: val_matthews_correlation did not improve from 0.09028
# Epoch 5/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1780 - matthews_correlation: 0.1278 - val_loss: 0.1837 - val_matthews_correlation: 0.0771
#
# Epoch 00005: val_matthews_correlation did not improve from 0.09028
# Epoch 6/50
# 2323/2323 [==============================] - 1s 510us/step - loss: 0.1576 - matthews_correlation: 0.3415 - val_loss: 0.2088 - val_matthews_correlation: 0.2898
#
# Epoch 00006: val_matthews_correlation improved from 0.09028 to 0.28984, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1452 - matthews_correlation: 0.3619 - val_loss: 0.1193 - val_matthews_correlation: 0.5955
#
# Epoch 00007: val_matthews_correlation improved from 0.28984 to 0.59555, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.1237 - matthews_correlation: 0.5493 - val_loss: 0.1216 - val_matthews_correlation: 0.5890
#
# Epoch 00008: val_matthews_correlation did not improve from 0.59555
# Epoch 9/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.1270 - matthews_correlation: 0.5964 - val_loss: 0.1365 - val_matthews_correlation: 0.5969
#
# Epoch 00009: val_matthews_correlation improved from 0.59555 to 0.59692, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1144 - matthews_correlation: 0.6055 - val_loss: 0.1178 - val_matthews_correlation: 0.5957
#
# Epoch 00010: val_matthews_correlation did not improve from 0.59692
# Epoch 11/50
# 2323/2323 [==============================] - 1s 511us/step - loss: 0.1216 - matthews_correlation: 0.6294 - val_loss: 0.1209 - val_matthews_correlation: 0.6148
#
# Epoch 00011: val_matthews_correlation improved from 0.59692 to 0.61480, saving model to weights_1.h5
# Epoch 12/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.1082 - matthews_correlation: 0.6775 - val_loss: 0.1104 - val_matthews_correlation: 0.6079
#
# Epoch 00012: val_matthews_correlation did not improve from 0.61480
# Epoch 13/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.1066 - matthews_correlation: 0.6380 - val_loss: 0.1132 - val_matthews_correlation: 0.6303
#
# Epoch 00013: val_matthews_correlation improved from 0.61480 to 0.63029, saving model to weights_1.h5
# Epoch 14/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.1034 - matthews_correlation: 0.6568 - val_loss: 0.1120 - val_matthews_correlation: 0.6282
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63029
# Epoch 15/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0978 - matthews_correlation: 0.7161 - val_loss: 0.1138 - val_matthews_correlation: 0.5913
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63029
# Epoch 16/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.0982 - matthews_correlation: 0.6828 - val_loss: 0.1114 - val_matthews_correlation: 0.6137
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63029
# Epoch 17/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0939 - matthews_correlation: 0.6915 - val_loss: 0.1097 - val_matthews_correlation: 0.6417
#
# Epoch 00017: val_matthews_correlation improved from 0.63029 to 0.64173, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0953 - matthews_correlation: 0.6744 - val_loss: 0.1218 - val_matthews_correlation: 0.5921
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64173
# Epoch 19/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0995 - matthews_correlation: 0.6932 - val_loss: 0.1173 - val_matthews_correlation: 0.6319
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64173
# Epoch 20/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0954 - matthews_correlation: 0.6690 - val_loss: 0.1365 - val_matthews_correlation: 0.5994
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64173
# Epoch 21/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0944 - matthews_correlation: 0.6982 - val_loss: 0.1144 - val_matthews_correlation: 0.6137
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64173
# Epoch 22/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0927 - matthews_correlation: 0.6729 - val_loss: 0.1078 - val_matthews_correlation: 0.6175
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64173
# Epoch 23/50
# 2323/2323 [==============================] - 1s 511us/step - loss: 0.0894 - matthews_correlation: 0.6905 - val_loss: 0.1194 - val_matthews_correlation: 0.5864
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64173
# Epoch 24/50
# 2323/2323 [==============================] - 1s 510us/step - loss: 0.0982 - matthews_correlation: 0.6729 - val_loss: 0.1116 - val_matthews_correlation: 0.6019
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64173
# Epoch 25/50
# 2323/2323 [==============================] - 1s 510us/step - loss: 0.0932 - matthews_correlation: 0.6666 - val_loss: 0.1246 - val_matthews_correlation: 0.6334
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64173
# Epoch 26/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.1015 - matthews_correlation: 0.6719 - val_loss: 0.1107 - val_matthews_correlation: 0.6115
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64173
# Epoch 27/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0961 - matthews_correlation: 0.6663 - val_loss: 0.1051 - val_matthews_correlation: 0.6918
#
# Epoch 00027: val_matthews_correlation improved from 0.64173 to 0.69184, saving model to weights_1.h5
# Epoch 28/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0913 - matthews_correlation: 0.6925 - val_loss: 0.1180 - val_matthews_correlation: 0.5811
#
# Epoch 00028: val_matthews_correlation did not improve from 0.69184
# Epoch 29/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0953 - matthews_correlation: 0.6866 - val_loss: 0.1151 - val_matthews_correlation: 0.7083
#
# Epoch 00029: val_matthews_correlation improved from 0.69184 to 0.70827, saving model to weights_1.h5
# Epoch 30/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.0897 - matthews_correlation: 0.7015 - val_loss: 0.1269 - val_matthews_correlation: 0.5442
#
# Epoch 00030: val_matthews_correlation did not improve from 0.70827
# Epoch 31/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0928 - matthews_correlation: 0.7074 - val_loss: 0.1041 - val_matthews_correlation: 0.6181
#
# Epoch 00031: val_matthews_correlation did not improve from 0.70827
# Epoch 32/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0913 - matthews_correlation: 0.6975 - val_loss: 0.1108 - val_matthews_correlation: 0.5019
#
# Epoch 00032: val_matthews_correlation did not improve from 0.70827
# Epoch 33/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0864 - matthews_correlation: 0.6975 - val_loss: 0.1023 - val_matthews_correlation: 0.6367
#
# Epoch 00033: val_matthews_correlation did not improve from 0.70827
# Epoch 34/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0878 - matthews_correlation: 0.6715 - val_loss: 0.1175 - val_matthews_correlation: 0.6504
#
# Epoch 00034: val_matthews_correlation did not improve from 0.70827
# Epoch 35/50
# 2323/2323 [==============================] - 1s 510us/step - loss: 0.0956 - matthews_correlation: 0.6481 - val_loss: 0.1119 - val_matthews_correlation: 0.7062
#
# Epoch 00035: val_matthews_correlation did not improve from 0.70827
# Epoch 36/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.0943 - matthews_correlation: 0.6095 - val_loss: 0.1090 - val_matthews_correlation: 0.6091
#
# Epoch 00036: val_matthews_correlation did not improve from 0.70827
# Epoch 37/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.0879 - matthews_correlation: 0.7092 - val_loss: 0.1158 - val_matthews_correlation: 0.5099
#
# Epoch 00037: val_matthews_correlation did not improve from 0.70827
# Epoch 38/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0877 - matthews_correlation: 0.7063 - val_loss: 0.1158 - val_matthews_correlation: 0.4952
#
# Epoch 00038: val_matthews_correlation did not improve from 0.70827
# Epoch 39/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0916 - matthews_correlation: 0.7001 - val_loss: 0.1147 - val_matthews_correlation: 0.5802
#
# Epoch 00039: val_matthews_correlation did not improve from 0.70827
# Epoch 40/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.0884 - matthews_correlation: 0.7148 - val_loss: 0.1053 - val_matthews_correlation: 0.6133
#
# Epoch 00040: val_matthews_correlation did not improve from 0.70827
# Epoch 41/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.1045 - matthews_correlation: 0.5300 - val_loss: 0.1100 - val_matthews_correlation: 0.5105
#
# Epoch 00041: val_matthews_correlation did not improve from 0.70827
# Epoch 42/50
# 2323/2323 [==============================] - 1s 511us/step - loss: 0.0917 - matthews_correlation: 0.7119 - val_loss: 0.1030 - val_matthews_correlation: 0.6484
#
# Epoch 00042: val_matthews_correlation did not improve from 0.70827
# Epoch 43/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0983 - matthews_correlation: 0.6140 - val_loss: 0.1024 - val_matthews_correlation: 0.6370
#
# Epoch 00043: val_matthews_correlation did not improve from 0.70827
# Epoch 44/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0940 - matthews_correlation: 0.6940 - val_loss: 0.1038 - val_matthews_correlation: 0.6287
#
# Epoch 00044: val_matthews_correlation did not improve from 0.70827
# Epoch 45/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0846 - matthews_correlation: 0.6701 - val_loss: 0.1071 - val_matthews_correlation: 0.6229
#
# Epoch 00045: val_matthews_correlation did not improve from 0.70827
# Epoch 46/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0867 - matthews_correlation: 0.6890 - val_loss: 0.1062 - val_matthews_correlation: 0.5229
#
# Epoch 00046: val_matthews_correlation did not improve from 0.70827
# Epoch 47/50
# 2323/2323 [==============================] - 1s 516us/step - loss: 0.0790 - matthews_correlation: 0.7238 - val_loss: 0.1089 - val_matthews_correlation: 0.5732
#
# Epoch 00047: val_matthews_correlation did not improve from 0.70827
# Epoch 48/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0769 - matthews_correlation: 0.6716 - val_loss: 0.1115 - val_matthews_correlation: 0.6193
#
# Epoch 00048: val_matthews_correlation did not improve from 0.70827
# Epoch 49/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.0838 - matthews_correlation: 0.6881 - val_loss: 0.1097 - val_matthews_correlation: 0.5274
#
# Epoch 00049: val_matthews_correlation did not improve from 0.70827
# Epoch 50/50
# 2323/2323 [==============================] - 1s 516us/step - loss: 0.0844 - matthews_correlation: 0.7106 - val_loss: 0.1159 - val_matthews_correlation: 0.6143
#
# Epoch 00050: val_matthews_correlation did not improve from 0.70827
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 989us/step - loss: 0.3410 - matthews_correlation: 0.0094 - val_loss: 0.2415 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.2293 - matthews_correlation: 0.0000e+00 - val_loss: 0.2183 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.2169 - matthews_correlation: 0.0000e+00 - val_loss: 0.1997 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.2012 - matthews_correlation: 0.0810 - val_loss: 0.1813 - val_matthews_correlation: 0.3564
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.35638, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1749 - matthews_correlation: 0.2929 - val_loss: 0.1670 - val_matthews_correlation: 0.4035
#
# Epoch 00005: val_matthews_correlation improved from 0.35638 to 0.40349, saving model to weights_2.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1732 - matthews_correlation: 0.3405 - val_loss: 0.3042 - val_matthews_correlation: 0.2505
#
# Epoch 00006: val_matthews_correlation did not improve from 0.40349
# Epoch 7/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.2257 - matthews_correlation: 0.0695 - val_loss: 0.2131 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.40349
# Epoch 8/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.2119 - matthews_correlation: 0.0000e+00 - val_loss: 0.2041 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.40349
# Epoch 9/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1789 - matthews_correlation: 0.0000e+00 - val_loss: 0.1693 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.40349
# Epoch 10/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.1823 - matthews_correlation: 0.1341 - val_loss: 0.1488 - val_matthews_correlation: 0.6188
#
# Epoch 00010: val_matthews_correlation improved from 0.40349 to 0.61882, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1675 - matthews_correlation: 0.4867 - val_loss: 0.2055 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00011: val_matthews_correlation did not improve from 0.61882
# Epoch 12/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.2048 - matthews_correlation: 0.0000e+00 - val_loss: 0.1916 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00012: val_matthews_correlation did not improve from 0.61882
# Epoch 13/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1802 - matthews_correlation: 0.0657 - val_loss: 0.2084 - val_matthews_correlation: 0.2937
#
# Epoch 00013: val_matthews_correlation did not improve from 0.61882
# Epoch 14/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1572 - matthews_correlation: 0.3176 - val_loss: 0.1346 - val_matthews_correlation: 0.3564
#
# Epoch 00014: val_matthews_correlation did not improve from 0.61882
# Epoch 15/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.1283 - matthews_correlation: 0.4792 - val_loss: 0.1525 - val_matthews_correlation: 0.4319
#
# Epoch 00015: val_matthews_correlation did not improve from 0.61882
# Epoch 16/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1348 - matthews_correlation: 0.4973 - val_loss: 0.1365 - val_matthews_correlation: 0.3553
#
# Epoch 00016: val_matthews_correlation did not improve from 0.61882
# Epoch 17/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.1272 - matthews_correlation: 0.4208 - val_loss: 0.1167 - val_matthews_correlation: 0.5528
#
# Epoch 00017: val_matthews_correlation did not improve from 0.61882
# Epoch 18/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1168 - matthews_correlation: 0.6301 - val_loss: 0.1249 - val_matthews_correlation: 0.4569
#
# Epoch 00018: val_matthews_correlation did not improve from 0.61882
# Epoch 19/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.1070 - matthews_correlation: 0.6040 - val_loss: 0.1141 - val_matthews_correlation: 0.6044
#
# Epoch 00019: val_matthews_correlation did not improve from 0.61882
# Epoch 20/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0989 - matthews_correlation: 0.6371 - val_loss: 0.1150 - val_matthews_correlation: 0.6285
#
# Epoch 00020: val_matthews_correlation improved from 0.61882 to 0.62847, saving model to weights_2.h5
# Epoch 21/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.1011 - matthews_correlation: 0.6773 - val_loss: 0.1165 - val_matthews_correlation: 0.5166
#
# Epoch 00021: val_matthews_correlation did not improve from 0.62847
# Epoch 22/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1054 - matthews_correlation: 0.6304 - val_loss: 0.1206 - val_matthews_correlation: 0.5873
#
# Epoch 00022: val_matthews_correlation did not improve from 0.62847
# Epoch 23/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1148 - matthews_correlation: 0.6555 - val_loss: 0.1171 - val_matthews_correlation: 0.5058
#
# Epoch 00023: val_matthews_correlation did not improve from 0.62847
# Epoch 24/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1020 - matthews_correlation: 0.6223 - val_loss: 0.1133 - val_matthews_correlation: 0.5159
#
# Epoch 00024: val_matthews_correlation did not improve from 0.62847
# Epoch 25/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.1037 - matthews_correlation: 0.6130 - val_loss: 0.1202 - val_matthews_correlation: 0.4623
#
# Epoch 00025: val_matthews_correlation did not improve from 0.62847
# Epoch 26/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1043 - matthews_correlation: 0.6222 - val_loss: 0.1307 - val_matthews_correlation: 0.4469
#
# Epoch 00026: val_matthews_correlation did not improve from 0.62847
# Epoch 27/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0996 - matthews_correlation: 0.6464 - val_loss: 0.1171 - val_matthews_correlation: 0.6057
#
# Epoch 00027: val_matthews_correlation did not improve from 0.62847
# Epoch 28/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0943 - matthews_correlation: 0.6865 - val_loss: 0.1106 - val_matthews_correlation: 0.6206
#
# Epoch 00028: val_matthews_correlation did not improve from 0.62847
# Epoch 29/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0914 - matthews_correlation: 0.6820 - val_loss: 0.1264 - val_matthews_correlation: 0.5182
#
# Epoch 00029: val_matthews_correlation did not improve from 0.62847
# Epoch 30/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.1053 - matthews_correlation: 0.6639 - val_loss: 0.1366 - val_matthews_correlation: 0.3515
#
# Epoch 00030: val_matthews_correlation did not improve from 0.62847
# Epoch 31/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1068 - matthews_correlation: 0.6309 - val_loss: 0.1118 - val_matthews_correlation: 0.6174
#
# Epoch 00031: val_matthews_correlation did not improve from 0.62847
# Epoch 32/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0903 - matthews_correlation: 0.7176 - val_loss: 0.1187 - val_matthews_correlation: 0.5678
#
# Epoch 00032: val_matthews_correlation did not improve from 0.62847
# Epoch 33/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0934 - matthews_correlation: 0.6955 - val_loss: 0.1235 - val_matthews_correlation: 0.6245
#
# Epoch 00033: val_matthews_correlation did not improve from 0.62847
# Epoch 34/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.0898 - matthews_correlation: 0.6253 - val_loss: 0.1185 - val_matthews_correlation: 0.5525
#
# Epoch 00034: val_matthews_correlation did not improve from 0.62847
# Epoch 35/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.1017 - matthews_correlation: 0.6906 - val_loss: 0.1264 - val_matthews_correlation: 0.5622
#
# Epoch 00035: val_matthews_correlation did not improve from 0.62847
# Epoch 36/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0920 - matthews_correlation: 0.7250 - val_loss: 0.1210 - val_matthews_correlation: 0.6120
#
# Epoch 00036: val_matthews_correlation did not improve from 0.62847
# Epoch 37/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0881 - matthews_correlation: 0.7206 - val_loss: 0.1481 - val_matthews_correlation: 0.4811
#
# Epoch 00037: val_matthews_correlation did not improve from 0.62847
# Epoch 38/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0925 - matthews_correlation: 0.6981 - val_loss: 0.1166 - val_matthews_correlation: 0.5636
#
# Epoch 00038: val_matthews_correlation did not improve from 0.62847
# Epoch 39/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0877 - matthews_correlation: 0.7191 - val_loss: 0.1267 - val_matthews_correlation: 0.5681
#
# Epoch 00039: val_matthews_correlation did not improve from 0.62847
# Epoch 40/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0865 - matthews_correlation: 0.7101 - val_loss: 0.1254 - val_matthews_correlation: 0.5470
#
# Epoch 00040: val_matthews_correlation did not improve from 0.62847
# Epoch 41/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0852 - matthews_correlation: 0.6710 - val_loss: 0.1441 - val_matthews_correlation: 0.5378
#
# Epoch 00041: val_matthews_correlation did not improve from 0.62847
# Epoch 42/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0836 - matthews_correlation: 0.7306 - val_loss: 0.1259 - val_matthews_correlation: 0.5364
#
# Epoch 00042: val_matthews_correlation did not improve from 0.62847
# Epoch 43/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0830 - matthews_correlation: 0.7276 - val_loss: 0.1389 - val_matthews_correlation: 0.5745
#
# Epoch 00043: val_matthews_correlation did not improve from 0.62847
# Epoch 44/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0899 - matthews_correlation: 0.6851 - val_loss: 0.1219 - val_matthews_correlation: 0.6376
#
# Epoch 00044: val_matthews_correlation improved from 0.62847 to 0.63762, saving model to weights_2.h5
# Epoch 45/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0918 - matthews_correlation: 0.6487 - val_loss: 0.1198 - val_matthews_correlation: 0.6170
#
# Epoch 00045: val_matthews_correlation did not improve from 0.63762
# Epoch 46/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0868 - matthews_correlation: 0.7445 - val_loss: 0.1270 - val_matthews_correlation: 0.5470
#
# Epoch 00046: val_matthews_correlation did not improve from 0.63762
# Epoch 47/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0903 - matthews_correlation: 0.6919 - val_loss: 0.1204 - val_matthews_correlation: 0.5958
#
# Epoch 00047: val_matthews_correlation did not improve from 0.63762
# Epoch 48/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0820 - matthews_correlation: 0.7536 - val_loss: 0.1403 - val_matthews_correlation: 0.5923
#
# Epoch 00048: val_matthews_correlation did not improve from 0.63762
# Epoch 49/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0945 - matthews_correlation: 0.7032 - val_loss: 0.1271 - val_matthews_correlation: 0.4606
#
# Epoch 00049: val_matthews_correlation did not improve from 0.63762
# Epoch 50/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0921 - matthews_correlation: 0.6351 - val_loss: 0.1203 - val_matthews_correlation: 0.5300
#
# Epoch 00050: val_matthews_correlation did not improve from 0.63762
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 1ms/step - loss: 0.3277 - matthews_correlation: 0.0000e+00 - val_loss: 0.2269 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.2312 - matthews_correlation: 0.0000e+00 - val_loss: 0.2222 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.2259 - matthews_correlation: 0.0000e+00 - val_loss: 0.2253 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.2189 - matthews_correlation: 0.0504 - val_loss: 0.2052 - val_matthews_correlation: 0.1559
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.15588, saving model to weights_3.h5
# Epoch 5/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.2145 - matthews_correlation: 0.0299 - val_loss: 0.2034 - val_matthews_correlation: 0.0765
#
# Epoch 00005: val_matthews_correlation did not improve from 0.15588
# Epoch 6/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.2021 - matthews_correlation: 0.0289 - val_loss: 0.1859 - val_matthews_correlation: 0.1559
#
# Epoch 00006: val_matthews_correlation did not improve from 0.15588
# Epoch 7/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1885 - matthews_correlation: 0.2538 - val_loss: 0.1798 - val_matthews_correlation: 0.3274
#
# Epoch 00007: val_matthews_correlation improved from 0.15588 to 0.32736, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.1808 - matthews_correlation: 0.1364 - val_loss: 0.1639 - val_matthews_correlation: 0.3184
#
# Epoch 00008: val_matthews_correlation did not improve from 0.32736
# Epoch 9/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.1477 - matthews_correlation: 0.4465 - val_loss: 0.1606 - val_matthews_correlation: 0.5650
#
# Epoch 00009: val_matthews_correlation improved from 0.32736 to 0.56496, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.1711 - matthews_correlation: 0.0781 - val_loss: 0.1478 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00010: val_matthews_correlation did not improve from 0.56496
# Epoch 11/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.1263 - matthews_correlation: 0.3671 - val_loss: 0.1268 - val_matthews_correlation: 0.4704
#
# Epoch 00011: val_matthews_correlation did not improve from 0.56496
# Epoch 12/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.1129 - matthews_correlation: 0.6137 - val_loss: 0.1097 - val_matthews_correlation: 0.5393
#
# Epoch 00012: val_matthews_correlation did not improve from 0.56496
# Epoch 13/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.1117 - matthews_correlation: 0.6344 - val_loss: 0.1143 - val_matthews_correlation: 0.5502
#
# Epoch 00013: val_matthews_correlation did not improve from 0.56496
# Epoch 14/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.1046 - matthews_correlation: 0.6751 - val_loss: 0.1116 - val_matthews_correlation: 0.6862
#
# Epoch 00014: val_matthews_correlation improved from 0.56496 to 0.68617, saving model to weights_3.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.1055 - matthews_correlation: 0.6348 - val_loss: 0.1028 - val_matthews_correlation: 0.6436
#
# Epoch 00015: val_matthews_correlation did not improve from 0.68617
# Epoch 16/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.1002 - matthews_correlation: 0.6482 - val_loss: 0.1031 - val_matthews_correlation: 0.6289
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68617
# Epoch 17/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0957 - matthews_correlation: 0.6641 - val_loss: 0.1043 - val_matthews_correlation: 0.6289
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68617
# Epoch 18/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.0968 - matthews_correlation: 0.6588 - val_loss: 0.1056 - val_matthews_correlation: 0.6165
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68617
# Epoch 19/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0979 - matthews_correlation: 0.6673 - val_loss: 0.1185 - val_matthews_correlation: 0.4872
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68617
# Epoch 20/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.1040 - matthews_correlation: 0.6460 - val_loss: 0.1089 - val_matthews_correlation: 0.6362
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68617
# Epoch 21/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.1099 - matthews_correlation: 0.5437 - val_loss: 0.1010 - val_matthews_correlation: 0.6356
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68617
# Epoch 22/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0961 - matthews_correlation: 0.6961 - val_loss: 0.1024 - val_matthews_correlation: 0.5378
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68617
# Epoch 23/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.1001 - matthews_correlation: 0.6793 - val_loss: 0.1056 - val_matthews_correlation: 0.7080
#
# Epoch 00023: val_matthews_correlation improved from 0.68617 to 0.70802, saving model to weights_3.h5
# Epoch 24/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0936 - matthews_correlation: 0.6839 - val_loss: 0.1038 - val_matthews_correlation: 0.6323
#
# Epoch 00024: val_matthews_correlation did not improve from 0.70802
# Epoch 25/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0941 - matthews_correlation: 0.6691 - val_loss: 0.1095 - val_matthews_correlation: 0.5618
#
# Epoch 00025: val_matthews_correlation did not improve from 0.70802
# Epoch 26/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0918 - matthews_correlation: 0.6394 - val_loss: 0.1012 - val_matthews_correlation: 0.6670
#
# Epoch 00026: val_matthews_correlation did not improve from 0.70802
# Epoch 27/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0900 - matthews_correlation: 0.6837 - val_loss: 0.1023 - val_matthews_correlation: 0.6480
#
# Epoch 00027: val_matthews_correlation did not improve from 0.70802
# Epoch 28/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0930 - matthews_correlation: 0.6509 - val_loss: 0.0990 - val_matthews_correlation: 0.6679
#
# Epoch 00028: val_matthews_correlation did not improve from 0.70802
# Epoch 29/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.0947 - matthews_correlation: 0.6947 - val_loss: 0.1201 - val_matthews_correlation: 0.4204
#
# Epoch 00029: val_matthews_correlation did not improve from 0.70802
# Epoch 30/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0948 - matthews_correlation: 0.6696 - val_loss: 0.1129 - val_matthews_correlation: 0.5234
#
# Epoch 00030: val_matthews_correlation did not improve from 0.70802
# Epoch 31/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0893 - matthews_correlation: 0.7018 - val_loss: 0.1027 - val_matthews_correlation: 0.5787
#
# Epoch 00031: val_matthews_correlation did not improve from 0.70802
# Epoch 32/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0866 - matthews_correlation: 0.6786 - val_loss: 0.1049 - val_matthews_correlation: 0.6322
#
# Epoch 00032: val_matthews_correlation did not improve from 0.70802
# Epoch 33/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0856 - matthews_correlation: 0.7379 - val_loss: 0.1032 - val_matthews_correlation: 0.6993
#
# Epoch 00033: val_matthews_correlation did not improve from 0.70802
# Epoch 34/50
# 2324/2324 [==============================] - 1s 506us/step - loss: 0.0880 - matthews_correlation: 0.6888 - val_loss: 0.1062 - val_matthews_correlation: 0.6455
#
# Epoch 00034: val_matthews_correlation did not improve from 0.70802
# Epoch 35/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0916 - matthews_correlation: 0.6566 - val_loss: 0.0970 - val_matthews_correlation: 0.6670
#
# Epoch 00035: val_matthews_correlation did not improve from 0.70802
# Epoch 36/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0882 - matthews_correlation: 0.6324 - val_loss: 0.1007 - val_matthews_correlation: 0.6977
#
# Epoch 00036: val_matthews_correlation did not improve from 0.70802
# Epoch 37/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0845 - matthews_correlation: 0.7279 - val_loss: 0.1153 - val_matthews_correlation: 0.5197
#
# Epoch 00037: val_matthews_correlation did not improve from 0.70802
# Epoch 38/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0891 - matthews_correlation: 0.6715 - val_loss: 0.1065 - val_matthews_correlation: 0.5686
#
# Epoch 00038: val_matthews_correlation did not improve from 0.70802
# Epoch 39/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0839 - matthews_correlation: 0.7222 - val_loss: 0.1127 - val_matthews_correlation: 0.6161
#
# Epoch 00039: val_matthews_correlation did not improve from 0.70802
# Epoch 40/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0873 - matthews_correlation: 0.7216 - val_loss: 0.1200 - val_matthews_correlation: 0.4629
#
# Epoch 00040: val_matthews_correlation did not improve from 0.70802
# Epoch 41/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0850 - matthews_correlation: 0.6825 - val_loss: 0.1108 - val_matthews_correlation: 0.5578
#
# Epoch 00041: val_matthews_correlation did not improve from 0.70802
# Epoch 42/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.0897 - matthews_correlation: 0.6575 - val_loss: 0.1048 - val_matthews_correlation: 0.6779
#
# Epoch 00042: val_matthews_correlation did not improve from 0.70802
# Epoch 43/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0903 - matthews_correlation: 0.6854 - val_loss: 0.1064 - val_matthews_correlation: 0.6593
#
# Epoch 00043: val_matthews_correlation did not improve from 0.70802
# Epoch 44/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0892 - matthews_correlation: 0.6846 - val_loss: 0.1100 - val_matthews_correlation: 0.6836
#
# Epoch 00044: val_matthews_correlation did not improve from 0.70802
# Epoch 45/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0876 - matthews_correlation: 0.6621 - val_loss: 0.0966 - val_matthews_correlation: 0.7005
#
# Epoch 00045: val_matthews_correlation did not improve from 0.70802
# Epoch 46/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0830 - matthews_correlation: 0.6748 - val_loss: 0.0998 - val_matthews_correlation: 0.7266
#
# Epoch 00046: val_matthews_correlation improved from 0.70802 to 0.72656, saving model to weights_3.h5
# Epoch 47/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0808 - matthews_correlation: 0.7102 - val_loss: 0.1152 - val_matthews_correlation: 0.6538
#
# Epoch 00047: val_matthews_correlation did not improve from 0.72656
# Epoch 48/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0809 - matthews_correlation: 0.6820 - val_loss: 0.1079 - val_matthews_correlation: 0.7199
#
# Epoch 00048: val_matthews_correlation did not improve from 0.72656
# Epoch 49/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0794 - matthews_correlation: 0.7318 - val_loss: 0.1104 - val_matthews_correlation: 0.6840
#
# Epoch 00049: val_matthews_correlation did not improve from 0.72656
# Epoch 50/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0819 - matthews_correlation: 0.6983 - val_loss: 0.1076 - val_matthews_correlation: 0.6120
#
# Epoch 00050: val_matthews_correlation did not improve from 0.72656
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 1ms/step - loss: 0.3495 - matthews_correlation: -0.0032 - val_loss: 0.2230 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.2268 - matthews_correlation: 0.0000e+00 - val_loss: 0.2079 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.2219 - matthews_correlation: 0.0000e+00 - val_loss: 0.2022 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.2106 - matthews_correlation: 0.0038 - val_loss: 0.1923 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.1952 - matthews_correlation: 0.0235 - val_loss: 0.1870 - val_matthews_correlation: 0.3887
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.38873, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.1931 - matthews_correlation: 0.0730 - val_loss: 0.1864 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.38873
# Epoch 7/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1768 - matthews_correlation: -0.0024 - val_loss: 0.1728 - val_matthews_correlation: 0.0673
#
# Epoch 00007: val_matthews_correlation did not improve from 0.38873
# Epoch 8/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.1660 - matthews_correlation: -0.0055 - val_loss: 0.1578 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.38873
# Epoch 9/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.1331 - matthews_correlation: 0.2883 - val_loss: 0.1230 - val_matthews_correlation: 0.5583
#
# Epoch 00009: val_matthews_correlation improved from 0.38873 to 0.55833, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.1137 - matthews_correlation: 0.6266 - val_loss: 0.1341 - val_matthews_correlation: 0.5406
#
# Epoch 00010: val_matthews_correlation did not improve from 0.55833
# Epoch 11/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.1173 - matthews_correlation: 0.4580 - val_loss: 0.1396 - val_matthews_correlation: 0.6042
#
# Epoch 00011: val_matthews_correlation improved from 0.55833 to 0.60420, saving model to weights_4.h5
# Epoch 12/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1134 - matthews_correlation: 0.6154 - val_loss: 0.1307 - val_matthews_correlation: 0.5712
#
# Epoch 00012: val_matthews_correlation did not improve from 0.60420
# Epoch 13/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.1258 - matthews_correlation: 0.4005 - val_loss: 0.1122 - val_matthews_correlation: 0.5773
#
# Epoch 00013: val_matthews_correlation did not improve from 0.60420
# Epoch 14/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.1061 - matthews_correlation: 0.6606 - val_loss: 0.1136 - val_matthews_correlation: 0.6189
#
# Epoch 00014: val_matthews_correlation improved from 0.60420 to 0.61895, saving model to weights_4.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.1039 - matthews_correlation: 0.6626 - val_loss: 0.1178 - val_matthews_correlation: 0.5759
#
# Epoch 00015: val_matthews_correlation did not improve from 0.61895
# Epoch 16/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.1003 - matthews_correlation: 0.6472 - val_loss: 0.1076 - val_matthews_correlation: 0.6488
#
# Epoch 00016: val_matthews_correlation improved from 0.61895 to 0.64882, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0940 - matthews_correlation: 0.6843 - val_loss: 0.1444 - val_matthews_correlation: 0.4073
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64882
# Epoch 18/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0983 - matthews_correlation: 0.6060 - val_loss: 0.1176 - val_matthews_correlation: 0.5798
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64882
# Epoch 19/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.0909 - matthews_correlation: 0.6982 - val_loss: 0.1083 - val_matthews_correlation: 0.5863
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64882
# Epoch 20/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0908 - matthews_correlation: 0.6546 - val_loss: 0.1213 - val_matthews_correlation: 0.4318
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64882
# Epoch 21/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.0947 - matthews_correlation: 0.6143 - val_loss: 0.1045 - val_matthews_correlation: 0.6157
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64882
# Epoch 22/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.0885 - matthews_correlation: 0.7070 - val_loss: 0.1092 - val_matthews_correlation: 0.5658
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64882
# Epoch 23/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.0931 - matthews_correlation: 0.5651 - val_loss: 0.1090 - val_matthews_correlation: 0.5619
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64882
# Epoch 24/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0855 - matthews_correlation: 0.7333 - val_loss: 0.1038 - val_matthews_correlation: 0.6667
#
# Epoch 00024: val_matthews_correlation improved from 0.64882 to 0.66672, saving model to weights_4.h5
# Epoch 25/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0996 - matthews_correlation: 0.6077 - val_loss: 0.1083 - val_matthews_correlation: 0.6382
#
# Epoch 00025: val_matthews_correlation did not improve from 0.66672
# Epoch 26/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0911 - matthews_correlation: 0.6655 - val_loss: 0.1138 - val_matthews_correlation: 0.5723
#
# Epoch 00026: val_matthews_correlation did not improve from 0.66672
# Epoch 27/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.0891 - matthews_correlation: 0.6547 - val_loss: 0.1183 - val_matthews_correlation: 0.4996
#
# Epoch 00027: val_matthews_correlation did not improve from 0.66672
# Epoch 28/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0835 - matthews_correlation: 0.6868 - val_loss: 0.1246 - val_matthews_correlation: 0.4733
#
# Epoch 00028: val_matthews_correlation did not improve from 0.66672
# Epoch 29/50
# 2324/2324 [==============================] - 1s 506us/step - loss: 0.0825 - matthews_correlation: 0.7022 - val_loss: 0.1110 - val_matthews_correlation: 0.5703
#
# Epoch 00029: val_matthews_correlation did not improve from 0.66672
# Epoch 30/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.0895 - matthews_correlation: 0.7063 - val_loss: 0.1142 - val_matthews_correlation: 0.6043
#
# Epoch 00030: val_matthews_correlation did not improve from 0.66672
# Epoch 31/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0856 - matthews_correlation: 0.6787 - val_loss: 0.1048 - val_matthews_correlation: 0.6416
#
# Epoch 00031: val_matthews_correlation did not improve from 0.66672
# Epoch 32/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.0884 - matthews_correlation: 0.6699 - val_loss: 0.1083 - val_matthews_correlation: 0.6509
#
# Epoch 00032: val_matthews_correlation did not improve from 0.66672
# Epoch 33/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0832 - matthews_correlation: 0.7240 - val_loss: 0.1202 - val_matthews_correlation: 0.3977
#
# Epoch 00033: val_matthews_correlation did not improve from 0.66672
# Epoch 34/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0850 - matthews_correlation: 0.6766 - val_loss: 0.1093 - val_matthews_correlation: 0.5754
#
# Epoch 00034: val_matthews_correlation did not improve from 0.66672
# Epoch 35/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0830 - matthews_correlation: 0.7320 - val_loss: 0.1072 - val_matthews_correlation: 0.6141
#
# Epoch 00035: val_matthews_correlation did not improve from 0.66672
# Epoch 36/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1081 - matthews_correlation: 0.6475 - val_loss: 0.1055 - val_matthews_correlation: 0.6116
#
# Epoch 00036: val_matthews_correlation did not improve from 0.66672
# Epoch 37/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0919 - matthews_correlation: 0.6574 - val_loss: 0.1082 - val_matthews_correlation: 0.6258
#
# Epoch 00037: val_matthews_correlation did not improve from 0.66672
# Epoch 38/50
# 2324/2324 [==============================] - 1s 516us/step - loss: 0.0959 - matthews_correlation: 0.6827 - val_loss: 0.1106 - val_matthews_correlation: 0.5756
#
# Epoch 00038: val_matthews_correlation did not improve from 0.66672
# Epoch 39/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0852 - matthews_correlation: 0.6925 - val_loss: 0.1054 - val_matthews_correlation: 0.6310
#
# Epoch 00039: val_matthews_correlation did not improve from 0.66672
# Epoch 40/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0840 - matthews_correlation: 0.7033 - val_loss: 0.1241 - val_matthews_correlation: 0.6007
#
# Epoch 00040: val_matthews_correlation did not improve from 0.66672
# Epoch 41/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0933 - matthews_correlation: 0.6879 - val_loss: 0.1138 - val_matthews_correlation: 0.6084
#
# Epoch 00041: val_matthews_correlation did not improve from 0.66672
# Epoch 42/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0847 - matthews_correlation: 0.7312 - val_loss: 0.1137 - val_matthews_correlation: 0.5760
#
# Epoch 00042: val_matthews_correlation did not improve from 0.66672
# Epoch 43/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0883 - matthews_correlation: 0.7035 - val_loss: 0.1032 - val_matthews_correlation: 0.6060
#
# Epoch 00043: val_matthews_correlation did not improve from 0.66672
# Epoch 44/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0797 - matthews_correlation: 0.7137 - val_loss: 0.1164 - val_matthews_correlation: 0.5996
#
# Epoch 00044: val_matthews_correlation did not improve from 0.66672
# Epoch 45/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0831 - matthews_correlation: 0.6989 - val_loss: 0.1114 - val_matthews_correlation: 0.5696
#
# Epoch 00045: val_matthews_correlation did not improve from 0.66672
# Epoch 46/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0851 - matthews_correlation: 0.6224 - val_loss: 0.1241 - val_matthews_correlation: 0.6123
#
# Epoch 00046: val_matthews_correlation did not improve from 0.66672
# Epoch 47/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0813 - matthews_correlation: 0.7282 - val_loss: 0.1082 - val_matthews_correlation: 0.5810
#
# Epoch 00047: val_matthews_correlation did not improve from 0.66672
# Epoch 48/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0820 - matthews_correlation: 0.7201 - val_loss: 0.1151 - val_matthews_correlation: 0.5855
#
# Epoch 00048: val_matthews_correlation did not improve from 0.66672
# Epoch 49/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.0780 - matthews_correlation: 0.7034 - val_loss: 0.1218 - val_matthews_correlation: 0.6274
#
# Epoch 00049: val_matthews_correlation did not improve from 0.66672
# Epoch 50/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0858 - matthews_correlation: 0.7146 - val_loss: 0.1160 - val_matthews_correlation: 0.4907
#
# Epoch 00050: val_matthews_correlation did not improve from 0.66672
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:23<00:00,  2.72it/s]

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/metadata_test.csv')
# Out:
# CPU times: user 7.67 ms, sys: 2.08 ms, total: 9.75 ms
# Wall time: 23.5 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:21<00:00, 14.35it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.31it/s]
# 100%|██████████| 2033/2033 [02:22<00:00, 14.21it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.47it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.22it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.26it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.10it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.26it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.48it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.31it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.61it/s]
# CPU times: user 25min 38s, sys: 33.5 s, total: 26min 11s
# Wall time: 26min 59s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 140us/step
# 6779/6779 [==============================] - 1s 134us/step
# 6779/6779 [==============================] - 1s 135us/step
# 6779/6779 [==============================] - 1s 136us/step
# 6779/6779 [==============================] - 1s 135us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
