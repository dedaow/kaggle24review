# %% [markdown]
# ### Thanks to this kernel :
#
# 1. https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
from keras.constraints import maxnorm
from keras.layers import Activation, Dense,TimeDistributed
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/vsb-power-line-fault-detection/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../input/vsb-power-line-fault-detection/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
#  80%|████████  | 1165/1452 [04:38<01:09,  4.16it/s]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
#     x = Activation('relu')(x)
#     x = Dropout(0.25)(x)
#     x = BatchNormalization()(x)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
#     x = Activation('relu')(x)
#     x = Dropout(0.25)(x)
#     x = BatchNormalization()(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = Attention(input_shape[1])(x)
    
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64, activation="relu")(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# model = model_lstm(train_X.shape)
# model.load_weights("../input/transformer-baseline-0-672-lb/weights_4.h5")

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
#     model.load_weights("../input/transformer-baseline-0-672-lb/weights_4.h5")
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 6s 3ms/step - loss: 0.2559 - matthews_correlation: 0.1074 - val_loss: 0.1867 - val_matthews_correlation: 0.3444
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.34439, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 497us/step - loss: 0.1561 - matthews_correlation: 0.2057 - val_loss: 0.1227 - val_matthews_correlation: 0.3487
#
# Epoch 00002: val_matthews_correlation improved from 0.34439 to 0.34871, saving model to weights_0.h5
# Epoch 3/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.1296 - matthews_correlation: 0.4393 - val_loss: 0.1124 - val_matthews_correlation: 0.4297
#
# Epoch 00003: val_matthews_correlation improved from 0.34871 to 0.42972, saving model to weights_0.h5
# Epoch 4/50
# 2322/2322 [==============================] - 1s 494us/step - loss: 0.1218 - matthews_correlation: 0.5267 - val_loss: 0.1026 - val_matthews_correlation: 0.5348
#
# Epoch 00004: val_matthews_correlation improved from 0.42972 to 0.53481, saving model to weights_0.h5
# Epoch 5/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.1137 - matthews_correlation: 0.4939 - val_loss: 0.2039 - val_matthews_correlation: 0.3113
#
# Epoch 00005: val_matthews_correlation did not improve from 0.53481
# Epoch 6/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.1068 - matthews_correlation: 0.6019 - val_loss: 0.0996 - val_matthews_correlation: 0.7314
#
# Epoch 00006: val_matthews_correlation improved from 0.53481 to 0.73142, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.1194 - matthews_correlation: 0.5614 - val_loss: 0.1239 - val_matthews_correlation: 0.4461
#
# Epoch 00007: val_matthews_correlation did not improve from 0.73142
# Epoch 8/50
# 2322/2322 [==============================] - 1s 497us/step - loss: 0.1066 - matthews_correlation: 0.6219 - val_loss: 0.0908 - val_matthews_correlation: 0.6713
#
# Epoch 00008: val_matthews_correlation did not improve from 0.73142
# Epoch 9/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.1031 - matthews_correlation: 0.6045 - val_loss: 0.0800 - val_matthews_correlation: 0.7233
#
# Epoch 00009: val_matthews_correlation did not improve from 0.73142
# Epoch 10/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.1001 - matthews_correlation: 0.6335 - val_loss: 0.1470 - val_matthews_correlation: 0.4168
#
# Epoch 00010: val_matthews_correlation did not improve from 0.73142
# Epoch 11/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.1005 - matthews_correlation: 0.6175 - val_loss: 0.0952 - val_matthews_correlation: 0.6954
#
# Epoch 00011: val_matthews_correlation did not improve from 0.73142
# Epoch 12/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.1010 - matthews_correlation: 0.6601 - val_loss: 0.0987 - val_matthews_correlation: 0.4839
#
# Epoch 00012: val_matthews_correlation did not improve from 0.73142
# Epoch 13/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0986 - matthews_correlation: 0.6492 - val_loss: 0.0933 - val_matthews_correlation: 0.7139
#
# Epoch 00013: val_matthews_correlation did not improve from 0.73142
# Epoch 14/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0994 - matthews_correlation: 0.5829 - val_loss: 0.0798 - val_matthews_correlation: 0.7209
#
# Epoch 00014: val_matthews_correlation did not improve from 0.73142
# Epoch 15/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.0966 - matthews_correlation: 0.6200 - val_loss: 0.0737 - val_matthews_correlation: 0.7622
#
# Epoch 00015: val_matthews_correlation improved from 0.73142 to 0.76220, saving model to weights_0.h5
# Epoch 16/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.0917 - matthews_correlation: 0.6591 - val_loss: 0.0782 - val_matthews_correlation: 0.7425
#
# Epoch 00016: val_matthews_correlation did not improve from 0.76220
# Epoch 17/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0942 - matthews_correlation: 0.6743 - val_loss: 0.0800 - val_matthews_correlation: 0.7547
#
# Epoch 00017: val_matthews_correlation did not improve from 0.76220
# Epoch 18/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0943 - matthews_correlation: 0.6469 - val_loss: 0.0858 - val_matthews_correlation: 0.7467
#
# Epoch 00018: val_matthews_correlation did not improve from 0.76220
# Epoch 19/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.1013 - matthews_correlation: 0.5817 - val_loss: 0.1464 - val_matthews_correlation: 0.6411
#
# Epoch 00019: val_matthews_correlation did not improve from 0.76220
# Epoch 20/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.0966 - matthews_correlation: 0.6585 - val_loss: 0.0858 - val_matthews_correlation: 0.6953
#
# Epoch 00020: val_matthews_correlation did not improve from 0.76220
# Epoch 21/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.0949 - matthews_correlation: 0.6846 - val_loss: 0.1030 - val_matthews_correlation: 0.7319
#
# Epoch 00021: val_matthews_correlation did not improve from 0.76220
# Epoch 22/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.0964 - matthews_correlation: 0.6594 - val_loss: 0.1033 - val_matthews_correlation: 0.6871
#
# Epoch 00022: val_matthews_correlation did not improve from 0.76220
# Epoch 23/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0880 - matthews_correlation: 0.6722 - val_loss: 0.0906 - val_matthews_correlation: 0.7077
#
# Epoch 00023: val_matthews_correlation did not improve from 0.76220
# Epoch 24/50
# 2322/2322 [==============================] - 1s 497us/step - loss: 0.0941 - matthews_correlation: 0.6394 - val_loss: 0.0816 - val_matthews_correlation: 0.7557
#
# Epoch 00024: val_matthews_correlation did not improve from 0.76220
# Epoch 25/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.0931 - matthews_correlation: 0.6649 - val_loss: 0.0883 - val_matthews_correlation: 0.7209
#
# Epoch 00025: val_matthews_correlation did not improve from 0.76220
# Epoch 26/50
# 2322/2322 [==============================] - 1s 497us/step - loss: 0.0925 - matthews_correlation: 0.5990 - val_loss: 0.0769 - val_matthews_correlation: 0.7493
#
# Epoch 00026: val_matthews_correlation did not improve from 0.76220
# Epoch 27/50
# 2322/2322 [==============================] - 1s 497us/step - loss: 0.0907 - matthews_correlation: 0.6813 - val_loss: 0.0903 - val_matthews_correlation: 0.6803
#
# Epoch 00027: val_matthews_correlation did not improve from 0.76220
# Epoch 28/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.0882 - matthews_correlation: 0.7160 - val_loss: 0.1028 - val_matthews_correlation: 0.5666
#
# Epoch 00028: val_matthews_correlation did not improve from 0.76220
# Epoch 29/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0943 - matthews_correlation: 0.6789 - val_loss: 0.0800 - val_matthews_correlation: 0.7493
#
# Epoch 00029: val_matthews_correlation did not improve from 0.76220
# Epoch 30/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.0937 - matthews_correlation: 0.6468 - val_loss: 0.1714 - val_matthews_correlation: 0.5940
#
# Epoch 00030: val_matthews_correlation did not improve from 0.76220
# Epoch 31/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0952 - matthews_correlation: 0.6501 - val_loss: 0.0818 - val_matthews_correlation: 0.7399
#
# Epoch 00031: val_matthews_correlation did not improve from 0.76220
# Epoch 32/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0906 - matthews_correlation: 0.6645 - val_loss: 0.0873 - val_matthews_correlation: 0.6855
#
# Epoch 00032: val_matthews_correlation did not improve from 0.76220
# Epoch 33/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.0894 - matthews_correlation: 0.6894 - val_loss: 0.0817 - val_matthews_correlation: 0.7969
#
# Epoch 00033: val_matthews_correlation improved from 0.76220 to 0.79692, saving model to weights_0.h5
# Epoch 34/50
# 2322/2322 [==============================] - 1s 506us/step - loss: 0.0839 - matthews_correlation: 0.7087 - val_loss: 0.0891 - val_matthews_correlation: 0.6200
#
# Epoch 00034: val_matthews_correlation did not improve from 0.79692
# Epoch 35/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0863 - matthews_correlation: 0.6918 - val_loss: 0.0781 - val_matthews_correlation: 0.8327
#
# Epoch 00035: val_matthews_correlation improved from 0.79692 to 0.83273, saving model to weights_0.h5
# Epoch 36/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0927 - matthews_correlation: 0.6096 - val_loss: 0.1777 - val_matthews_correlation: 0.6415
#
# Epoch 00036: val_matthews_correlation did not improve from 0.83273
# Epoch 37/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.0941 - matthews_correlation: 0.6947 - val_loss: 0.0938 - val_matthews_correlation: 0.8169
#
# Epoch 00037: val_matthews_correlation did not improve from 0.83273
# Epoch 38/50
# 2322/2322 [==============================] - 1s 503us/step - loss: 0.0920 - matthews_correlation: 0.6473 - val_loss: 0.0778 - val_matthews_correlation: 0.7717
#
# Epoch 00038: val_matthews_correlation did not improve from 0.83273
# Epoch 39/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.0905 - matthews_correlation: 0.6249 - val_loss: 0.0882 - val_matthews_correlation: 0.7137
#
# Epoch 00039: val_matthews_correlation did not improve from 0.83273
# Epoch 40/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.0829 - matthews_correlation: 0.6984 - val_loss: 0.0807 - val_matthews_correlation: 0.8064
#
# Epoch 00040: val_matthews_correlation did not improve from 0.83273
# Epoch 41/50
# 2322/2322 [==============================] - 1s 503us/step - loss: 0.0850 - matthews_correlation: 0.6995 - val_loss: 0.0774 - val_matthews_correlation: 0.7808
#
# Epoch 00041: val_matthews_correlation did not improve from 0.83273
# Epoch 42/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0793 - matthews_correlation: 0.7424 - val_loss: 0.0920 - val_matthews_correlation: 0.7906
#
# Epoch 00042: val_matthews_correlation did not improve from 0.83273
# Epoch 43/50
# 2322/2322 [==============================] - 1s 499us/step - loss: 0.0805 - matthews_correlation: 0.7239 - val_loss: 0.0833 - val_matthews_correlation: 0.7834
#
# Epoch 00043: val_matthews_correlation did not improve from 0.83273
# Epoch 44/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.0841 - matthews_correlation: 0.6341 - val_loss: 0.0801 - val_matthews_correlation: 0.7466
#
# Epoch 00044: val_matthews_correlation did not improve from 0.83273
# Epoch 45/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0857 - matthews_correlation: 0.6481 - val_loss: 0.0816 - val_matthews_correlation: 0.7496
#
# Epoch 00045: val_matthews_correlation did not improve from 0.83273
# Epoch 46/50
# 2322/2322 [==============================] - 1s 501us/step - loss: 0.0816 - matthews_correlation: 0.7152 - val_loss: 0.1408 - val_matthews_correlation: 0.6885
#
# Epoch 00046: val_matthews_correlation did not improve from 0.83273
# Epoch 47/50
# 2322/2322 [==============================] - 1s 502us/step - loss: 0.1014 - matthews_correlation: 0.6552 - val_loss: 0.0976 - val_matthews_correlation: 0.7086
#
# Epoch 00047: val_matthews_correlation did not improve from 0.83273
# Epoch 48/50
# 2322/2322 [==============================] - 1s 501us/step - loss: 0.0884 - matthews_correlation: 0.6826 - val_loss: 0.1066 - val_matthews_correlation: 0.5278
#
# Epoch 00048: val_matthews_correlation did not improve from 0.83273
# Epoch 49/50
# 2322/2322 [==============================] - 1s 501us/step - loss: 0.0812 - matthews_correlation: 0.6872 - val_loss: 0.0786 - val_matthews_correlation: 0.7488
#
# Epoch 00049: val_matthews_correlation did not improve from 0.83273
# Epoch 50/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.0770 - matthews_correlation: 0.7127 - val_loss: 0.0791 - val_matthews_correlation: 0.8062
#
# Epoch 00050: val_matthews_correlation did not improve from 0.83273
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2658 - matthews_correlation: 0.1781 - val_loss: 0.1917 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.1620 - matthews_correlation: 0.2583 - val_loss: 0.1442 - val_matthews_correlation: 0.1236
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.12359, saving model to weights_1.h5
# Epoch 3/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1333 - matthews_correlation: 0.3809 - val_loss: 0.1344 - val_matthews_correlation: 0.4449
#
# Epoch 00003: val_matthews_correlation improved from 0.12359 to 0.44495, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.1161 - matthews_correlation: 0.5652 - val_loss: 0.1803 - val_matthews_correlation: 0.1061
#
# Epoch 00004: val_matthews_correlation did not improve from 0.44495
# Epoch 5/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1147 - matthews_correlation: 0.5281 - val_loss: 0.1535 - val_matthews_correlation: 0.3279
#
# Epoch 00005: val_matthews_correlation did not improve from 0.44495
# Epoch 6/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.1025 - matthews_correlation: 0.6464 - val_loss: 0.1816 - val_matthews_correlation: 0.5501
#
# Epoch 00006: val_matthews_correlation improved from 0.44495 to 0.55007, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1036 - matthews_correlation: 0.6445 - val_loss: 0.1186 - val_matthews_correlation: 0.5794
#
# Epoch 00007: val_matthews_correlation improved from 0.55007 to 0.57942, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0947 - matthews_correlation: 0.6244 - val_loss: 0.1179 - val_matthews_correlation: 0.6451
#
# Epoch 00008: val_matthews_correlation improved from 0.57942 to 0.64512, saving model to weights_1.h5
# Epoch 9/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0996 - matthews_correlation: 0.6675 - val_loss: 0.1446 - val_matthews_correlation: 0.1932
#
# Epoch 00009: val_matthews_correlation did not improve from 0.64512
# Epoch 10/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.1004 - matthews_correlation: 0.6468 - val_loss: 0.1288 - val_matthews_correlation: 0.4010
#
# Epoch 00010: val_matthews_correlation did not improve from 0.64512
# Epoch 11/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1083 - matthews_correlation: 0.5779 - val_loss: 0.1338 - val_matthews_correlation: 0.5288
#
# Epoch 00011: val_matthews_correlation did not improve from 0.64512
# Epoch 12/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.1012 - matthews_correlation: 0.6418 - val_loss: 0.1222 - val_matthews_correlation: 0.6092
#
# Epoch 00012: val_matthews_correlation did not improve from 0.64512
# Epoch 13/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.1035 - matthews_correlation: 0.6566 - val_loss: 0.1024 - val_matthews_correlation: 0.6189
#
# Epoch 00013: val_matthews_correlation did not improve from 0.64512
# Epoch 14/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0938 - matthews_correlation: 0.5975 - val_loss: 0.1340 - val_matthews_correlation: 0.4954
#
# Epoch 00014: val_matthews_correlation did not improve from 0.64512
# Epoch 15/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0940 - matthews_correlation: 0.6941 - val_loss: 0.1117 - val_matthews_correlation: 0.6343
#
# Epoch 00015: val_matthews_correlation did not improve from 0.64512
# Epoch 16/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0944 - matthews_correlation: 0.6610 - val_loss: 0.0991 - val_matthews_correlation: 0.6383
#
# Epoch 00016: val_matthews_correlation did not improve from 0.64512
# Epoch 17/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0893 - matthews_correlation: 0.6746 - val_loss: 0.1106 - val_matthews_correlation: 0.6039
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64512
# Epoch 18/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0900 - matthews_correlation: 0.6594 - val_loss: 0.1168 - val_matthews_correlation: 0.6770
#
# Epoch 00018: val_matthews_correlation improved from 0.64512 to 0.67699, saving model to weights_1.h5
# Epoch 19/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0954 - matthews_correlation: 0.6427 - val_loss: 0.1772 - val_matthews_correlation: 0.3694
#
# Epoch 00019: val_matthews_correlation did not improve from 0.67699
# Epoch 20/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0904 - matthews_correlation: 0.6964 - val_loss: 0.1052 - val_matthews_correlation: 0.6591
#
# Epoch 00020: val_matthews_correlation did not improve from 0.67699
# Epoch 21/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0907 - matthews_correlation: 0.7235 - val_loss: 0.1208 - val_matthews_correlation: 0.6454
#
# Epoch 00021: val_matthews_correlation did not improve from 0.67699
# Epoch 22/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0957 - matthews_correlation: 0.6370 - val_loss: 0.1070 - val_matthews_correlation: 0.6185
#
# Epoch 00022: val_matthews_correlation did not improve from 0.67699
# Epoch 23/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0900 - matthews_correlation: 0.7153 - val_loss: 0.1023 - val_matthews_correlation: 0.6458
#
# Epoch 00023: val_matthews_correlation did not improve from 0.67699
# Epoch 24/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0932 - matthews_correlation: 0.6796 - val_loss: 0.1236 - val_matthews_correlation: 0.6199
#
# Epoch 00024: val_matthews_correlation did not improve from 0.67699
# Epoch 25/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0895 - matthews_correlation: 0.6956 - val_loss: 0.1025 - val_matthews_correlation: 0.6728
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67699
# Epoch 26/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0963 - matthews_correlation: 0.7243 - val_loss: 0.1167 - val_matthews_correlation: 0.6052
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67699
# Epoch 27/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0890 - matthews_correlation: 0.6871 - val_loss: 0.1057 - val_matthews_correlation: 0.6463
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67699
# Epoch 28/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1093 - matthews_correlation: 0.6102 - val_loss: 0.5775 - val_matthews_correlation: 0.3262
#
# Epoch 00028: val_matthews_correlation did not improve from 0.67699
# Epoch 29/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0966 - matthews_correlation: 0.7090 - val_loss: 0.1200 - val_matthews_correlation: 0.6373
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67699
# Epoch 30/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0949 - matthews_correlation: 0.6887 - val_loss: 0.1437 - val_matthews_correlation: 0.5288
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67699
# Epoch 31/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0914 - matthews_correlation: 0.6771 - val_loss: 0.1078 - val_matthews_correlation: 0.6758
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67699
# Epoch 32/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0884 - matthews_correlation: 0.7081 - val_loss: 0.1027 - val_matthews_correlation: 0.6869
#
# Epoch 00032: val_matthews_correlation improved from 0.67699 to 0.68693, saving model to weights_1.h5
# Epoch 33/50
# 2323/2323 [==============================] - 1s 508us/step - loss: 0.0863 - matthews_correlation: 0.6663 - val_loss: 0.1070 - val_matthews_correlation: 0.6537
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68693
# Epoch 34/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0881 - matthews_correlation: 0.6702 - val_loss: 0.1941 - val_matthews_correlation: 0.5337
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68693
# Epoch 35/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.1008 - matthews_correlation: 0.6369 - val_loss: 0.1055 - val_matthews_correlation: 0.6335
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68693
# Epoch 36/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0860 - matthews_correlation: 0.7171 - val_loss: 0.1304 - val_matthews_correlation: 0.4861
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68693
# Epoch 37/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0898 - matthews_correlation: 0.6955 - val_loss: 0.1155 - val_matthews_correlation: 0.5252
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68693
# Epoch 38/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0829 - matthews_correlation: 0.7189 - val_loss: 0.0979 - val_matthews_correlation: 0.6769
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68693
# Epoch 39/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0845 - matthews_correlation: 0.6983 - val_loss: 0.1393 - val_matthews_correlation: 0.4696
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68693
# Epoch 40/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0857 - matthews_correlation: 0.7136 - val_loss: 0.1637 - val_matthews_correlation: 0.5305
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68693
# Epoch 41/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0758 - matthews_correlation: 0.7147 - val_loss: 0.0920 - val_matthews_correlation: 0.6703
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68693
# Epoch 42/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0796 - matthews_correlation: 0.6889 - val_loss: 0.1100 - val_matthews_correlation: 0.6600
#
# Epoch 00042: val_matthews_correlation did not improve from 0.68693
# Epoch 43/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0766 - matthews_correlation: 0.6964 - val_loss: 0.1158 - val_matthews_correlation: 0.6202
#
# Epoch 00043: val_matthews_correlation did not improve from 0.68693
# Epoch 44/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0829 - matthews_correlation: 0.7180 - val_loss: 0.1164 - val_matthews_correlation: 0.5786
#
# Epoch 00044: val_matthews_correlation did not improve from 0.68693
# Epoch 45/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0798 - matthews_correlation: 0.7134 - val_loss: 0.1084 - val_matthews_correlation: 0.7026
#
# Epoch 00045: val_matthews_correlation improved from 0.68693 to 0.70255, saving model to weights_1.h5
# Epoch 46/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0819 - matthews_correlation: 0.7038 - val_loss: 0.1030 - val_matthews_correlation: 0.5857
#
# Epoch 00046: val_matthews_correlation did not improve from 0.70255
# Epoch 47/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0817 - matthews_correlation: 0.7560 - val_loss: 0.1205 - val_matthews_correlation: 0.6259
#
# Epoch 00047: val_matthews_correlation did not improve from 0.70255
# Epoch 48/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0880 - matthews_correlation: 0.6920 - val_loss: 0.1288 - val_matthews_correlation: 0.5282
#
# Epoch 00048: val_matthews_correlation did not improve from 0.70255
# Epoch 49/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0837 - matthews_correlation: 0.6877 - val_loss: 0.1113 - val_matthews_correlation: 0.6614
#
# Epoch 00049: val_matthews_correlation did not improve from 0.70255
# Epoch 50/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0813 - matthews_correlation: 0.7290 - val_loss: 0.1207 - val_matthews_correlation: 0.5954
#
# Epoch 00050: val_matthews_correlation did not improve from 0.70255
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.3104 - matthews_correlation: 0.1236 - val_loss: 0.1914 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1570 - matthews_correlation: 0.1581 - val_loss: 0.1316 - val_matthews_correlation: 0.3355
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.33552, saving model to weights_2.h5
# Epoch 3/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.1191 - matthews_correlation: 0.5047 - val_loss: 0.1338 - val_matthews_correlation: 0.5765
#
# Epoch 00003: val_matthews_correlation improved from 0.33552 to 0.57653, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.1165 - matthews_correlation: 0.5469 - val_loss: 0.2028 - val_matthews_correlation: 0.4604
#
# Epoch 00004: val_matthews_correlation did not improve from 0.57653
# Epoch 5/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1187 - matthews_correlation: 0.4787 - val_loss: 0.1568 - val_matthews_correlation: 0.0757
#
# Epoch 00005: val_matthews_correlation did not improve from 0.57653
# Epoch 6/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.1078 - matthews_correlation: 0.5865 - val_loss: 0.1262 - val_matthews_correlation: 0.6304
#
# Epoch 00006: val_matthews_correlation improved from 0.57653 to 0.63042, saving model to weights_2.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.1023 - matthews_correlation: 0.6408 - val_loss: 0.1190 - val_matthews_correlation: 0.5470
#
# Epoch 00007: val_matthews_correlation did not improve from 0.63042
# Epoch 8/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.1032 - matthews_correlation: 0.6039 - val_loss: 0.1174 - val_matthews_correlation: 0.6479
#
# Epoch 00008: val_matthews_correlation improved from 0.63042 to 0.64789, saving model to weights_2.h5
# Epoch 9/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.1202 - matthews_correlation: 0.5842 - val_loss: 0.1135 - val_matthews_correlation: 0.6582
#
# Epoch 00009: val_matthews_correlation improved from 0.64789 to 0.65817, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0990 - matthews_correlation: 0.6443 - val_loss: 0.1643 - val_matthews_correlation: 0.1837
#
# Epoch 00010: val_matthews_correlation did not improve from 0.65817
# Epoch 11/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0981 - matthews_correlation: 0.6302 - val_loss: 0.1177 - val_matthews_correlation: 0.4651
#
# Epoch 00011: val_matthews_correlation did not improve from 0.65817
# Epoch 12/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0968 - matthews_correlation: 0.6127 - val_loss: 0.1187 - val_matthews_correlation: 0.6368
#
# Epoch 00012: val_matthews_correlation did not improve from 0.65817
# Epoch 13/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0915 - matthews_correlation: 0.6987 - val_loss: 0.1207 - val_matthews_correlation: 0.5757
#
# Epoch 00013: val_matthews_correlation did not improve from 0.65817
# Epoch 14/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.0900 - matthews_correlation: 0.6908 - val_loss: 0.1156 - val_matthews_correlation: 0.5549
#
# Epoch 00014: val_matthews_correlation did not improve from 0.65817
# Epoch 15/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0944 - matthews_correlation: 0.6971 - val_loss: 0.1175 - val_matthews_correlation: 0.5805
#
# Epoch 00015: val_matthews_correlation did not improve from 0.65817
# Epoch 16/50
# 2323/2323 [==============================] - 1s 505us/step - loss: 0.0937 - matthews_correlation: 0.6363 - val_loss: 0.1243 - val_matthews_correlation: 0.5136
#
# Epoch 00016: val_matthews_correlation did not improve from 0.65817
# Epoch 17/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0904 - matthews_correlation: 0.6971 - val_loss: 0.1206 - val_matthews_correlation: 0.6766
#
# Epoch 00017: val_matthews_correlation improved from 0.65817 to 0.67658, saving model to weights_2.h5
# Epoch 18/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0933 - matthews_correlation: 0.6433 - val_loss: 0.1153 - val_matthews_correlation: 0.6575
#
# Epoch 00018: val_matthews_correlation did not improve from 0.67658
# Epoch 19/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0865 - matthews_correlation: 0.7282 - val_loss: 0.1110 - val_matthews_correlation: 0.6678
#
# Epoch 00019: val_matthews_correlation did not improve from 0.67658
# Epoch 20/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.0900 - matthews_correlation: 0.7093 - val_loss: 0.1229 - val_matthews_correlation: 0.6479
#
# Epoch 00020: val_matthews_correlation did not improve from 0.67658
# Epoch 21/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0993 - matthews_correlation: 0.6771 - val_loss: 0.1159 - val_matthews_correlation: 0.6569
#
# Epoch 00021: val_matthews_correlation did not improve from 0.67658
# Epoch 22/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0916 - matthews_correlation: 0.6806 - val_loss: 0.1288 - val_matthews_correlation: 0.4209
#
# Epoch 00022: val_matthews_correlation did not improve from 0.67658
# Epoch 23/50
# 2323/2323 [==============================] - 1s 498us/step - loss: 0.0883 - matthews_correlation: 0.6701 - val_loss: 0.1116 - val_matthews_correlation: 0.5852
#
# Epoch 00023: val_matthews_correlation did not improve from 0.67658
# Epoch 24/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0859 - matthews_correlation: 0.7318 - val_loss: 0.1106 - val_matthews_correlation: 0.5976
#
# Epoch 00024: val_matthews_correlation did not improve from 0.67658
# Epoch 25/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0873 - matthews_correlation: 0.7477 - val_loss: 0.1225 - val_matthews_correlation: 0.6381
#
# Epoch 00025: val_matthews_correlation did not improve from 0.67658
# Epoch 26/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0842 - matthews_correlation: 0.7176 - val_loss: 0.1168 - val_matthews_correlation: 0.6626
#
# Epoch 00026: val_matthews_correlation did not improve from 0.67658
# Epoch 27/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0853 - matthews_correlation: 0.7289 - val_loss: 0.1169 - val_matthews_correlation: 0.6228
#
# Epoch 00027: val_matthews_correlation did not improve from 0.67658
# Epoch 28/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0882 - matthews_correlation: 0.6703 - val_loss: 0.1129 - val_matthews_correlation: 0.5715
#
# Epoch 00028: val_matthews_correlation did not improve from 0.67658
# Epoch 29/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0818 - matthews_correlation: 0.7184 - val_loss: 0.1224 - val_matthews_correlation: 0.6368
#
# Epoch 00029: val_matthews_correlation did not improve from 0.67658
# Epoch 30/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0821 - matthews_correlation: 0.7510 - val_loss: 0.1400 - val_matthews_correlation: 0.5372
#
# Epoch 00030: val_matthews_correlation did not improve from 0.67658
# Epoch 31/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0835 - matthews_correlation: 0.7405 - val_loss: 0.1248 - val_matthews_correlation: 0.5637
#
# Epoch 00031: val_matthews_correlation did not improve from 0.67658
# Epoch 32/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0896 - matthews_correlation: 0.6547 - val_loss: 0.1155 - val_matthews_correlation: 0.6019
#
# Epoch 00032: val_matthews_correlation did not improve from 0.67658
# Epoch 33/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0794 - matthews_correlation: 0.7665 - val_loss: 0.1700 - val_matthews_correlation: 0.4094
#
# Epoch 00033: val_matthews_correlation did not improve from 0.67658
# Epoch 34/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0779 - matthews_correlation: 0.7417 - val_loss: 0.1272 - val_matthews_correlation: 0.6400
#
# Epoch 00034: val_matthews_correlation did not improve from 0.67658
# Epoch 35/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0771 - matthews_correlation: 0.7305 - val_loss: 0.1161 - val_matthews_correlation: 0.5613
#
# Epoch 00035: val_matthews_correlation did not improve from 0.67658
# Epoch 36/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0771 - matthews_correlation: 0.7410 - val_loss: 0.1432 - val_matthews_correlation: 0.5362
#
# Epoch 00036: val_matthews_correlation did not improve from 0.67658
# Epoch 37/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0731 - matthews_correlation: 0.7635 - val_loss: 0.1192 - val_matthews_correlation: 0.6747
#
# Epoch 00037: val_matthews_correlation did not improve from 0.67658
# Epoch 38/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0752 - matthews_correlation: 0.7464 - val_loss: 0.1880 - val_matthews_correlation: 0.1416
#
# Epoch 00038: val_matthews_correlation did not improve from 0.67658
# Epoch 39/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0804 - matthews_correlation: 0.7206 - val_loss: 0.1314 - val_matthews_correlation: 0.6006
#
# Epoch 00039: val_matthews_correlation did not improve from 0.67658
# Epoch 40/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0854 - matthews_correlation: 0.7222 - val_loss: 0.1289 - val_matthews_correlation: 0.5502
#
# Epoch 00040: val_matthews_correlation did not improve from 0.67658
# Epoch 41/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0844 - matthews_correlation: 0.7323 - val_loss: 0.1167 - val_matthews_correlation: 0.6726
#
# Epoch 00041: val_matthews_correlation did not improve from 0.67658
# Epoch 42/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0753 - matthews_correlation: 0.7085 - val_loss: 0.1263 - val_matthews_correlation: 0.6975
#
# Epoch 00042: val_matthews_correlation improved from 0.67658 to 0.69750, saving model to weights_2.h5
# Epoch 43/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0814 - matthews_correlation: 0.6971 - val_loss: 0.1255 - val_matthews_correlation: 0.6522
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69750
# Epoch 44/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0757 - matthews_correlation: 0.7462 - val_loss: 0.1202 - val_matthews_correlation: 0.5758
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69750
# Epoch 45/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0715 - matthews_correlation: 0.7247 - val_loss: 0.1318 - val_matthews_correlation: 0.5759
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69750
# Epoch 46/50
# 2323/2323 [==============================] - 1s 502us/step - loss: 0.0679 - matthews_correlation: 0.7926 - val_loss: 0.1951 - val_matthews_correlation: 0.3198
#
# Epoch 00046: val_matthews_correlation did not improve from 0.69750
# Epoch 47/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0849 - matthews_correlation: 0.7273 - val_loss: 0.1494 - val_matthews_correlation: 0.5942
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69750
# Epoch 48/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.0807 - matthews_correlation: 0.7513 - val_loss: 0.1409 - val_matthews_correlation: 0.2882
#
# Epoch 00048: val_matthews_correlation did not improve from 0.69750
# Epoch 49/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.0753 - matthews_correlation: 0.7723 - val_loss: 0.1434 - val_matthews_correlation: 0.5467
#
# Epoch 00049: val_matthews_correlation did not improve from 0.69750
# Epoch 50/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0751 - matthews_correlation: 0.7338 - val_loss: 0.1200 - val_matthews_correlation: 0.5942
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69750
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2338 - matthews_correlation: 0.1252 - val_loss: 0.1776 - val_matthews_correlation: 0.2127
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.21267, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1533 - matthews_correlation: 0.2020 - val_loss: 0.2879 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.21267
# Epoch 3/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1325 - matthews_correlation: 0.4460 - val_loss: 0.1598 - val_matthews_correlation: 0.3889
#
# Epoch 00003: val_matthews_correlation improved from 0.21267 to 0.38893, saving model to weights_3.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.1130 - matthews_correlation: 0.5832 - val_loss: 0.1845 - val_matthews_correlation: 0.3483
#
# Epoch 00004: val_matthews_correlation did not improve from 0.38893
# Epoch 5/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1114 - matthews_correlation: 0.6024 - val_loss: 0.1141 - val_matthews_correlation: 0.4300
#
# Epoch 00005: val_matthews_correlation improved from 0.38893 to 0.43003, saving model to weights_3.h5
# Epoch 6/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1023 - matthews_correlation: 0.6679 - val_loss: 0.1557 - val_matthews_correlation: 0.4629
#
# Epoch 00006: val_matthews_correlation improved from 0.43003 to 0.46294, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1064 - matthews_correlation: 0.6228 - val_loss: 0.1164 - val_matthews_correlation: 0.5423
#
# Epoch 00007: val_matthews_correlation improved from 0.46294 to 0.54228, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1112 - matthews_correlation: 0.6124 - val_loss: 0.1177 - val_matthews_correlation: 0.4575
#
# Epoch 00008: val_matthews_correlation did not improve from 0.54228
# Epoch 9/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.1073 - matthews_correlation: 0.6237 - val_loss: 0.1198 - val_matthews_correlation: 0.4307
#
# Epoch 00009: val_matthews_correlation did not improve from 0.54228
# Epoch 10/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.1002 - matthews_correlation: 0.5978 - val_loss: 0.0982 - val_matthews_correlation: 0.5693
#
# Epoch 00010: val_matthews_correlation improved from 0.54228 to 0.56933, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1038 - matthews_correlation: 0.6717 - val_loss: 0.1185 - val_matthews_correlation: 0.5003
#
# Epoch 00011: val_matthews_correlation did not improve from 0.56933
# Epoch 12/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0962 - matthews_correlation: 0.6778 - val_loss: 0.1254 - val_matthews_correlation: 0.4388
#
# Epoch 00012: val_matthews_correlation did not improve from 0.56933
# Epoch 13/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0987 - matthews_correlation: 0.6384 - val_loss: 0.1274 - val_matthews_correlation: 0.4520
#
# Epoch 00013: val_matthews_correlation did not improve from 0.56933
# Epoch 14/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0949 - matthews_correlation: 0.6408 - val_loss: 0.1144 - val_matthews_correlation: 0.4384
#
# Epoch 00014: val_matthews_correlation did not improve from 0.56933
# Epoch 15/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0939 - matthews_correlation: 0.6683 - val_loss: 0.1018 - val_matthews_correlation: 0.6545
#
# Epoch 00015: val_matthews_correlation improved from 0.56933 to 0.65448, saving model to weights_3.h5
# Epoch 16/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0912 - matthews_correlation: 0.6680 - val_loss: 0.1315 - val_matthews_correlation: 0.4190
#
# Epoch 00016: val_matthews_correlation did not improve from 0.65448
# Epoch 17/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0963 - matthews_correlation: 0.6686 - val_loss: 0.1160 - val_matthews_correlation: 0.4418
#
# Epoch 00017: val_matthews_correlation did not improve from 0.65448
# Epoch 18/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0943 - matthews_correlation: 0.6495 - val_loss: 0.1677 - val_matthews_correlation: 0.4323
#
# Epoch 00018: val_matthews_correlation did not improve from 0.65448
# Epoch 19/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.1036 - matthews_correlation: 0.5879 - val_loss: 0.1023 - val_matthews_correlation: 0.6905
#
# Epoch 00019: val_matthews_correlation improved from 0.65448 to 0.69045, saving model to weights_3.h5
# Epoch 20/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0931 - matthews_correlation: 0.6700 - val_loss: 0.1278 - val_matthews_correlation: 0.4250
#
# Epoch 00020: val_matthews_correlation did not improve from 0.69045
# Epoch 21/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.0906 - matthews_correlation: 0.6689 - val_loss: 0.1274 - val_matthews_correlation: 0.4575
#
# Epoch 00021: val_matthews_correlation did not improve from 0.69045
# Epoch 22/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0902 - matthews_correlation: 0.6963 - val_loss: 0.1003 - val_matthews_correlation: 0.6734
#
# Epoch 00022: val_matthews_correlation did not improve from 0.69045
# Epoch 23/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0947 - matthews_correlation: 0.6796 - val_loss: 0.1166 - val_matthews_correlation: 0.3079
#
# Epoch 00023: val_matthews_correlation did not improve from 0.69045
# Epoch 24/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0944 - matthews_correlation: 0.6080 - val_loss: 0.1002 - val_matthews_correlation: 0.6858
#
# Epoch 00024: val_matthews_correlation did not improve from 0.69045
# Epoch 25/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0899 - matthews_correlation: 0.7214 - val_loss: 0.0944 - val_matthews_correlation: 0.5685
#
# Epoch 00025: val_matthews_correlation did not improve from 0.69045
# Epoch 26/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0891 - matthews_correlation: 0.6641 - val_loss: 0.1220 - val_matthews_correlation: 0.6685
#
# Epoch 00026: val_matthews_correlation did not improve from 0.69045
# Epoch 27/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0900 - matthews_correlation: 0.6705 - val_loss: 0.1049 - val_matthews_correlation: 0.6638
#
# Epoch 00027: val_matthews_correlation did not improve from 0.69045
# Epoch 28/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0836 - matthews_correlation: 0.7229 - val_loss: 0.0926 - val_matthews_correlation: 0.6883
#
# Epoch 00028: val_matthews_correlation did not improve from 0.69045
# Epoch 29/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0827 - matthews_correlation: 0.7183 - val_loss: 0.1110 - val_matthews_correlation: 0.6715
#
# Epoch 00029: val_matthews_correlation did not improve from 0.69045
# Epoch 30/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0866 - matthews_correlation: 0.7231 - val_loss: 0.1116 - val_matthews_correlation: 0.6693
#
# Epoch 00030: val_matthews_correlation did not improve from 0.69045
# Epoch 31/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0868 - matthews_correlation: 0.6593 - val_loss: 0.1089 - val_matthews_correlation: 0.6431
#
# Epoch 00031: val_matthews_correlation did not improve from 0.69045
# Epoch 32/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0837 - matthews_correlation: 0.6671 - val_loss: 0.1218 - val_matthews_correlation: 0.4607
#
# Epoch 00032: val_matthews_correlation did not improve from 0.69045
# Epoch 33/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0824 - matthews_correlation: 0.7357 - val_loss: 0.1022 - val_matthews_correlation: 0.6532
#
# Epoch 00033: val_matthews_correlation did not improve from 0.69045
# Epoch 34/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.0844 - matthews_correlation: 0.6649 - val_loss: 0.1565 - val_matthews_correlation: 0.5009
#
# Epoch 00034: val_matthews_correlation did not improve from 0.69045
# Epoch 35/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0798 - matthews_correlation: 0.7281 - val_loss: 0.0906 - val_matthews_correlation: 0.6655
#
# Epoch 00035: val_matthews_correlation did not improve from 0.69045
# Epoch 36/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0809 - matthews_correlation: 0.7309 - val_loss: 0.1607 - val_matthews_correlation: 0.3897
#
# Epoch 00036: val_matthews_correlation did not improve from 0.69045
# Epoch 37/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0850 - matthews_correlation: 0.6928 - val_loss: 0.1011 - val_matthews_correlation: 0.6702
#
# Epoch 00037: val_matthews_correlation did not improve from 0.69045
# Epoch 38/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0805 - matthews_correlation: 0.7376 - val_loss: 0.1220 - val_matthews_correlation: 0.6839
#
# Epoch 00038: val_matthews_correlation did not improve from 0.69045
# Epoch 39/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0917 - matthews_correlation: 0.6615 - val_loss: 0.1107 - val_matthews_correlation: 0.4275
#
# Epoch 00039: val_matthews_correlation did not improve from 0.69045
# Epoch 40/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0910 - matthews_correlation: 0.6725 - val_loss: 0.1144 - val_matthews_correlation: 0.6229
#
# Epoch 00040: val_matthews_correlation did not improve from 0.69045
# Epoch 41/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0849 - matthews_correlation: 0.7074 - val_loss: 0.1005 - val_matthews_correlation: 0.5164
#
# Epoch 00041: val_matthews_correlation did not improve from 0.69045
# Epoch 42/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0797 - matthews_correlation: 0.7163 - val_loss: 0.1125 - val_matthews_correlation: 0.6853
#
# Epoch 00042: val_matthews_correlation did not improve from 0.69045
# Epoch 43/50
# 2324/2324 [==============================] - 1s 503us/step - loss: 0.0837 - matthews_correlation: 0.7014 - val_loss: 0.0955 - val_matthews_correlation: 0.7236
#
# Epoch 00043: val_matthews_correlation improved from 0.69045 to 0.72358, saving model to weights_3.h5
# Epoch 44/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0760 - matthews_correlation: 0.7471 - val_loss: 0.1027 - val_matthews_correlation: 0.7260
#
# Epoch 00044: val_matthews_correlation improved from 0.72358 to 0.72601, saving model to weights_3.h5
# Epoch 45/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0718 - matthews_correlation: 0.7506 - val_loss: 0.1031 - val_matthews_correlation: 0.5762
#
# Epoch 00045: val_matthews_correlation did not improve from 0.72601
# Epoch 46/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0731 - matthews_correlation: 0.7363 - val_loss: 0.1053 - val_matthews_correlation: 0.6152
#
# Epoch 00046: val_matthews_correlation did not improve from 0.72601
# Epoch 47/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0756 - matthews_correlation: 0.7437 - val_loss: 0.0986 - val_matthews_correlation: 0.6952
#
# Epoch 00047: val_matthews_correlation did not improve from 0.72601
# Epoch 48/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0718 - matthews_correlation: 0.7530 - val_loss: 0.1105 - val_matthews_correlation: 0.5450
#
# Epoch 00048: val_matthews_correlation did not improve from 0.72601
# Epoch 49/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0713 - matthews_correlation: 0.7682 - val_loss: 0.1083 - val_matthews_correlation: 0.6026
#
# Epoch 00049: val_matthews_correlation did not improve from 0.72601
# Epoch 50/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0826 - matthews_correlation: 0.7259 - val_loss: 0.1041 - val_matthews_correlation: 0.7140
#
# Epoch 00050: val_matthews_correlation did not improve from 0.72601
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2345 - matthews_correlation: 0.0995 - val_loss: 0.1706 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1306 - matthews_correlation: 0.4119 - val_loss: 0.1559 - val_matthews_correlation: 0.4375
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.43751, saving model to weights_4.h5
# Epoch 3/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1164 - matthews_correlation: 0.5332 - val_loss: 0.1236 - val_matthews_correlation: 0.5934
#
# Epoch 00003: val_matthews_correlation improved from 0.43751 to 0.59344, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.1020 - matthews_correlation: 0.6141 - val_loss: 0.1382 - val_matthews_correlation: 0.2433
#
# Epoch 00004: val_matthews_correlation did not improve from 0.59344
# Epoch 5/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1064 - matthews_correlation: 0.6125 - val_loss: 0.1712 - val_matthews_correlation: 0.4110
#
# Epoch 00005: val_matthews_correlation did not improve from 0.59344
# Epoch 6/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0987 - matthews_correlation: 0.6469 - val_loss: 0.1339 - val_matthews_correlation: 0.3232
#
# Epoch 00006: val_matthews_correlation did not improve from 0.59344
# Epoch 7/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1078 - matthews_correlation: 0.5853 - val_loss: 0.1364 - val_matthews_correlation: 0.3716
#
# Epoch 00007: val_matthews_correlation did not improve from 0.59344
# Epoch 8/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0951 - matthews_correlation: 0.6453 - val_loss: 0.1335 - val_matthews_correlation: 0.4105
#
# Epoch 00008: val_matthews_correlation did not improve from 0.59344
# Epoch 9/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0910 - matthews_correlation: 0.6941 - val_loss: 0.1441 - val_matthews_correlation: 0.4230
#
# Epoch 00009: val_matthews_correlation did not improve from 0.59344
# Epoch 10/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0933 - matthews_correlation: 0.6912 - val_loss: 0.1397 - val_matthews_correlation: 0.6133
#
# Epoch 00010: val_matthews_correlation improved from 0.59344 to 0.61327, saving model to weights_4.h5
# Epoch 11/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0932 - matthews_correlation: 0.6639 - val_loss: 0.1394 - val_matthews_correlation: 0.5288
#
# Epoch 00011: val_matthews_correlation did not improve from 0.61327
# Epoch 12/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0927 - matthews_correlation: 0.6729 - val_loss: 0.1247 - val_matthews_correlation: 0.5871
#
# Epoch 00012: val_matthews_correlation did not improve from 0.61327
# Epoch 13/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0902 - matthews_correlation: 0.7186 - val_loss: 0.1151 - val_matthews_correlation: 0.5272
#
# Epoch 00013: val_matthews_correlation did not improve from 0.61327
# Epoch 14/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0879 - matthews_correlation: 0.6627 - val_loss: 0.1121 - val_matthews_correlation: 0.6298
#
# Epoch 00014: val_matthews_correlation improved from 0.61327 to 0.62985, saving model to weights_4.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0972 - matthews_correlation: 0.6839 - val_loss: 0.1387 - val_matthews_correlation: 0.3831
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62985
# Epoch 16/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0909 - matthews_correlation: 0.7484 - val_loss: 0.1316 - val_matthews_correlation: 0.5195
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62985
# Epoch 17/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0861 - matthews_correlation: 0.7118 - val_loss: 0.1289 - val_matthews_correlation: 0.6069
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62985
# Epoch 18/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0833 - matthews_correlation: 0.7115 - val_loss: 0.1264 - val_matthews_correlation: 0.5376
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62985
# Epoch 19/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0820 - matthews_correlation: 0.7257 - val_loss: 0.1496 - val_matthews_correlation: 0.5222
#
# Epoch 00019: val_matthews_correlation did not improve from 0.62985
# Epoch 20/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0832 - matthews_correlation: 0.7103 - val_loss: 0.1356 - val_matthews_correlation: 0.5758
#
# Epoch 00020: val_matthews_correlation did not improve from 0.62985
# Epoch 21/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0882 - matthews_correlation: 0.7277 - val_loss: 0.1233 - val_matthews_correlation: 0.4186
#
# Epoch 00021: val_matthews_correlation did not improve from 0.62985
# Epoch 22/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0891 - matthews_correlation: 0.6977 - val_loss: 0.1107 - val_matthews_correlation: 0.6520
#
# Epoch 00022: val_matthews_correlation improved from 0.62985 to 0.65198, saving model to weights_4.h5
# Epoch 23/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0812 - matthews_correlation: 0.7015 - val_loss: 0.1337 - val_matthews_correlation: 0.5622
#
# Epoch 00023: val_matthews_correlation did not improve from 0.65198
# Epoch 24/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0847 - matthews_correlation: 0.6773 - val_loss: 0.1165 - val_matthews_correlation: 0.5999
#
# Epoch 00024: val_matthews_correlation did not improve from 0.65198
# Epoch 25/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0850 - matthews_correlation: 0.7181 - val_loss: 0.1166 - val_matthews_correlation: 0.6011
#
# Epoch 00025: val_matthews_correlation did not improve from 0.65198
# Epoch 26/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0750 - matthews_correlation: 0.7690 - val_loss: 0.1684 - val_matthews_correlation: 0.5733
#
# Epoch 00026: val_matthews_correlation did not improve from 0.65198
# Epoch 27/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0739 - matthews_correlation: 0.7481 - val_loss: 0.1181 - val_matthews_correlation: 0.5790
#
# Epoch 00027: val_matthews_correlation did not improve from 0.65198
# Epoch 28/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0739 - matthews_correlation: 0.7458 - val_loss: 0.1455 - val_matthews_correlation: 0.5727
#
# Epoch 00028: val_matthews_correlation did not improve from 0.65198
# Epoch 29/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0806 - matthews_correlation: 0.7333 - val_loss: 0.1795 - val_matthews_correlation: 0.4540
#
# Epoch 00029: val_matthews_correlation did not improve from 0.65198
# Epoch 30/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0802 - matthews_correlation: 0.7287 - val_loss: 0.1059 - val_matthews_correlation: 0.6543
#
# Epoch 00030: val_matthews_correlation improved from 0.65198 to 0.65429, saving model to weights_4.h5
# Epoch 31/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0736 - matthews_correlation: 0.7707 - val_loss: 0.1361 - val_matthews_correlation: 0.5820
#
# Epoch 00031: val_matthews_correlation did not improve from 0.65429
# Epoch 32/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0696 - matthews_correlation: 0.7736 - val_loss: 0.1323 - val_matthews_correlation: 0.5893
#
# Epoch 00032: val_matthews_correlation did not improve from 0.65429
# Epoch 33/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0695 - matthews_correlation: 0.7775 - val_loss: 0.1196 - val_matthews_correlation: 0.6263
#
# Epoch 00033: val_matthews_correlation did not improve from 0.65429
# Epoch 34/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0701 - matthews_correlation: 0.7488 - val_loss: 0.1287 - val_matthews_correlation: 0.5948
#
# Epoch 00034: val_matthews_correlation did not improve from 0.65429
# Epoch 35/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0770 - matthews_correlation: 0.7014 - val_loss: 0.1328 - val_matthews_correlation: 0.5988
#
# Epoch 00035: val_matthews_correlation did not improve from 0.65429
# Epoch 36/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0773 - matthews_correlation: 0.7174 - val_loss: 0.1339 - val_matthews_correlation: 0.6354
#
# Epoch 00036: val_matthews_correlation did not improve from 0.65429
# Epoch 37/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0766 - matthews_correlation: 0.7498 - val_loss: 0.1435 - val_matthews_correlation: 0.4707
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65429
# Epoch 38/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0726 - matthews_correlation: 0.7667 - val_loss: 0.1287 - val_matthews_correlation: 0.6007
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65429
# Epoch 39/50
# 2324/2324 [==============================] - 1s 497us/step - loss: 0.0679 - matthews_correlation: 0.7439 - val_loss: 0.1284 - val_matthews_correlation: 0.5338
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65429
# Epoch 40/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0738 - matthews_correlation: 0.7504 - val_loss: 0.1279 - val_matthews_correlation: 0.5913
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65429
# Epoch 41/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0815 - matthews_correlation: 0.7100 - val_loss: 0.1877 - val_matthews_correlation: 0.5818
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65429
# Epoch 42/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0758 - matthews_correlation: 0.7441 - val_loss: 0.1356 - val_matthews_correlation: 0.5727
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65429
# Epoch 43/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0739 - matthews_correlation: 0.7790 - val_loss: 0.1562 - val_matthews_correlation: 0.5448
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65429
# Epoch 44/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0731 - matthews_correlation: 0.7657 - val_loss: 0.1223 - val_matthews_correlation: 0.5873
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65429
# Epoch 45/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0844 - matthews_correlation: 0.7316 - val_loss: 0.2545 - val_matthews_correlation: 0.4202
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65429
# Epoch 46/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0765 - matthews_correlation: 0.7556 - val_loss: 0.1316 - val_matthews_correlation: 0.6389
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65429
# Epoch 47/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0800 - matthews_correlation: 0.7646 - val_loss: 0.1617 - val_matthews_correlation: 0.6232
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65429
# Epoch 48/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0725 - matthews_correlation: 0.7902 - val_loss: 0.1298 - val_matthews_correlation: 0.6209
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65429
# Epoch 49/50
# 2324/2324 [==============================] - 1s 499us/step - loss: 0.0734 - matthews_correlation: 0.7264 - val_loss: 0.1184 - val_matthews_correlation: 0.6986
#
# Epoch 00049: val_matthews_correlation improved from 0.65429 to 0.69857, saving model to weights_4.h5
# Epoch 50/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0707 - matthews_correlation: 0.7659 - val_loss: 0.1229 - val_matthews_correlation: 0.6709
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69857
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:21<00:00,  3.09it/s]

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../input/vsb-power-line-fault-detection/metadata_test.csv')
# Out:
# CPU times: user 6.7 ms, sys: 3.14 ms, total: 9.83 ms
# Wall time: 22.4 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/vsb-power-line-fault-detection/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:25<00:00, 13.95it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 14.25it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 13.92it/s]
# 100%|██████████| 2033/2033 [02:26<00:00, 13.96it/s]
# 100%|██████████| 2033/2033 [02:25<00:00, 14.16it/s]
# 100%|██████████| 2033/2033 [02:25<00:00, 14.29it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 14.11it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 14.32it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 13.09it/s]
# 100%|██████████| 2033/2033 [02:27<00:00, 13.84it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.22it/s]
# CPU times: user 26min 2s, sys: 33.5 s, total: 26min 35s
# Wall time: 27min 57s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
submission = pd.read_csv('../input/vsb-power-line-fault-detection/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 133us/step
# 6779/6779 [==============================] - 1s 131us/step
# 6779/6779 [==============================] - 1s 131us/step
# 6779/6779 [==============================] - 1s 131us/step
# 6779/6779 [==============================] - 1s 131us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
